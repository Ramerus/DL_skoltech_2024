# %% [markdown]
# # Problem set 2 (30 + 35 = 65 pts)

# %% [markdown]
# ## Problem 1: Sentiment Analysis for E-commerce Reviews (Total: 30 pts)

# %% [markdown]
# <div style="align: center;">
#     <br>
#     <img src="https://storage.googleapis.com/kaggle-datasets-images/11827/16290/140ca3b71ec51512dcac444c57583f25/dataset-cover.jpg" style="display:block; margin:auto; width:95%; height:250px;">
# </div><br><br>
#
# <div style="letter-spacing:normal; opacity:1.;">
# <!--   https://xkcd.com/color/rgb/   -->
#   <p style="text-align:center; background-color: lightsalmon; color: Jaguar; border-radius:10px; font-family:monospace; border-radius:20px;
#             line-height:1.4; font-size:32px; font-weight:bold; text-transform: uppercase; padding: 9px;">
#             <strong>Women's E-Commerce Clothing Reviews</strong></p>

# %% [markdown]
# **Context** \\
# ​
# This is a Women’s Clothing E-Commerce dataset revolving around the reviews written by customers. Its nine supportive features offer a great environment to parse out the text through its multiple dimensions. Because this is real commercial data, it has been anonymized, and references to the company in the review text and body have been replaced with “retailer”.
# ​
# **Content**
# ​
# This dataset includes **`23486 rows`** and **`10 feature`** variables. Each row corresponds to a customer review, and includes the variables:
# ​
# - **Clothing ID:** Integer Categorical variable that refers to the **`specific piece`** being reviewed.
# - **Age:** Positive Integer variable of the **`reviewers age`**.
# - **Title:** String variable for the **`title of the review`**.
# - **Review Text:** String variable for the **`review body`**.
# - **Rating:** Positive Ordinal Integer variable for the **`product score`** granted by the customer from **`1 Worst, to 5 Best`**.
# - **Recommended IND:** Binary variable stating where the customer recommends the product where **`1 is recommended, 0 is not recommended`**.
# - **Positive Feedback Count:** Positive Integer documenting the **`number`** of other customers **`who found this review positive`**.
# - **Division Name:** Categorical name of the **`product high level division`**.
# - **Department Name:** Categorical name of the product **`department name`**.
# - **Class Name:** Categorical name of the **`product class name`**.
#
# **The dataset can be downloaded from lms canvas folder "dataset/Womens Clothing E-Commerce Reviews.zip"**
#
# This task is to predict whether customers recommend the product they purchased using the information in their review text.
# The model is to focus on finding reviews of products that are not recommended.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/Deep Learning/HW/Datasets/Womens Clothing E-Commerce Reviews.zip'
dataset_path = '/content/Womens Clothing E-Commerce Reviews.csv'
# !pip install contractions
# Out:
# Archive:  /content/drive/MyDrive/Deep Learning/HW/Datasets/Womens Clothing E-Commerce Reviews.zip
# replace Womens Clothing E-Commerce Reviews.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: Womens Clothing E-Commerce Reviews.csv
# Requirement already satisfied: contractions in /usr/local/lib/python3.10/dist-packages (0.1.73)
# Requirement already satisfied: textsearch>=0.0.21 in /usr/local/lib/python3.10/dist-packages (from contractions) (0.0.24)
# Requirement already satisfied: anyascii in /usr/local/lib/python3.10/dist-packages (from textsearch>=0.0.21->contractions) (0.3.2)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.10/dist-packages (from textsearch>=0.0.21->contractions) (2.1.0)

# %%
import pandas as pd
import numpy as np
import json
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.utils.rnn import pad_sequence
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader, Dataset
import re #regular expressions
import nltk #NLP: tokenization, stemming, lemmatization
from tqdm import tqdm
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, SnowballStemmer
# import contractions
from nltk import pos_tag
from sklearn.preprocessing import QuantileTransformer, LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score
from torchtext.vocab import Vocab, build_vocab_from_iterator
from torchtext.data.utils import get_tokenizer
from sklearn.model_selection import train_test_split
from collections import Counter
from itertools import chain
from transformers import BertTokenizer, BertForSequenceClassification, BertModel, BertTokenizer, BertConfig
from torch.utils.data.sampler import SequentialSampler
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import f1_score, recall_score, average_precision_score


nltk.download('stopwords') #list of stopwords that has to be deleted
nltk.download('wordnet') #lemmatization of words
nltk.download('punkt') #module for splitting text on sentences and words
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
seed_val = 42
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# %% [markdown]
# ### 1. Exploratory Data Analysis and Data Cleaning (2 pts)
# Read Dataframe, and explore it's shape and distribution of missing values

# %%
df = pd.read_csv(dataset_path)
print(df.shape)
missing_values = df.isnull().sum()
missing_values = missing_values[missing_values>0]
print(missing_values)
df.head(4)
# Out:
# (23486, 11)
# Title              3810
# Review Text         845
# Division Name        14
# Department Name      14
# Class Name           14
# dtype: int64
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants

# %% [markdown]
# ### 2. Feature Selection (2 pts)
# Identify relevant features for sentiment analysis and adjust column names for consistency and clarity (you need to define a column ["not_recommended"])

# %%
df = df.rename(columns={
    "Clothing ID":"product_id",
    "Age":"customer_age",
    "Title":"review_title",
    "Review Text":"review_text",
    "Rating":"review_rating",
    "Recommended IND":"recommended_product",
    "Positive Feedback Count":"positive_feedback_count",
    "Division Name":"product_division",
    "Department Name":"product_department",
    "Class Name":"product_class"})
df["not_recommended"] = np.where(df['recommended_product'] == 0, 1, 0)
assert (df["not_recommended"] + df['recommended_product']).unique() == [1]

#processing NaN values: categorical and text features can be replaced by empty values
for feature_name in ['review_title', 'review_text', 'product_division', 'product_department', 'product_class']:
  df.loc[df[feature_name].isnull(), feature_name] = '' #or df[feature_name] = df[feature_name].fillna('')
assert df.isnull().sum().unique() == [0]

# %% [markdown]
# ### 4. Text Preprocessing and Text Mining - NLTK (Natural Language Toolkit) (6 pts)
# - **Text Cleaning (1 pt)**
#     - Remove unnecessary characters, convert case, trim unnecessary spaces,...
# - **NLTK Tokenization (1 pt)**
#     - Split text into words or tokens.
# - **NLTK Stop Word Removal (1 pt)**
#     - Eliminate common words that do not add significant meaning.
# - **NLTK Normalization (1 pt)**
#     - Apply stemming and lemmatization.
# - **Handling Abbreviations and Acronyms (1 pt)**
#     - Expand abbreviations to their full forms.
# - **Removing Rare or Infrequent Words (1 pt)**
#     - Filter out rare words based on a set frequency threshold.

# %%
#dataset analysis
numerical_features_list = ['customer_age', 'review_rating', 'positive_feedback_count']
categorical_features_list = ['product_division', 'product_department', 'product_class']
text_features_list = ['review_text', 'review_title']
label_column = ['not_recommended']
df_processed = df[numerical_features_list+categorical_features_list+text_features_list+label_column].copy(deep=True)
print(df_processed[df_processed['not_recommended']==0].count().sum())
print(df_processed[df_processed['not_recommended']==1].count().sum())
#Calculate weights for imbalanced classification problem
class_weights = compute_class_weight('balanced', classes=df_processed['not_recommended'].unique(), y=df_processed['not_recommended'])
class_weights_tensor = torch.tensor(class_weights, dtype=torch.float32).to(device)
# Out:
# 173826
# 37548

# %%
#text concatenation
df_processed['combined_text'] = df_processed['review_text'] + ' ' + df_processed['review_title']
df_processed = df_processed.drop(text_features_list, axis=1)

#categorical feature processing
le = LabelEncoder()
df_processed[categorical_features_list] = df_processed[categorical_features_list].apply(lambda x: le.fit_transform(x.astype(str)))

#numerical feature processing
numerical_transformer = QuantileTransformer(output_distribution='uniform', n_quantiles=10)
df_processed[numerical_features_list] = numerical_transformer.fit_transform(df_processed[numerical_features_list])

# %%
df_processed.head()
# Out:
#    customer_age  review_rating  positive_feedback_count  product_division  \
# 0      0.222222       0.333333                 0.000000                 3
# 1      0.250000       1.000000                 0.814815                 1
# 2      0.888889       0.166667                 0.000000                 1
# 3      0.722222       1.000000                 0.000000                 2
# 4      0.666667       1.000000                 0.888889                 1
#
#    product_department  product_class  not_recommended  \
# 0                   3              6                0
# 1                   2              4                0
# 2                   2              4                1
# 3                   1             14                0
# 4                   5              1                0
#
#                                        combined_text
# 0  Absolutely wonderful - silky and sexy and comf...
# 1  Love this dress!  it's sooo pretty.  i happene...
# 2  I had such high hopes for this dress and reall...
# 3  I love, love, love this jumpsuit. it's fun, fl...
# 4  This shirt is very flattering to all due to th...

# %%
#Perform analysis of existing abbreviations

from collections import Counter

# reviews_text =
pattern = r"\b[A-Z]{2,}\b|\b[A-Za-z]+\.[A-Za-z]+\b|[a-z]'[a-z]"
abbreviations = []
df_processed['combined_text'] = df_processed['combined_text'].dropna().apply(contractions.fix) #fix most popular contractions

def find_context(string, substring, count=3, size=20):
    start = 0
    counter = 0
    contexts = []
    while counter!=count:
        index = string.find(substring, start)
        if index == -1:
            break
        contexts.append(string[index-size//2:index+size//2])
        start = index + 1
        counter += 1

    return contexts

for sample in df_processed['combined_text'].dropna():
    found = re.findall(pattern, sample)
    abbreviations.extend(found)

abbreviation_counts = Counter(abbreviations)
most_common_abbreviations = abbreviation_counts.most_common(30)
for abbrev in most_common_abbreviations:
  print(abbrev, 'contexts: ', find_context(' '.join(df_processed['combined_text'].dropna().apply(str)), abbrev[0]))

abbreviations_dict = {
    "tts": "true to size",
    "lot's": "a lot",
    "i.e": "that is",
    "dind't": "did not",
    "did't": "did not",
    "preggo's": "pregnant",
    "t.la": "the laundry alternative",
    "p.js":"pajamas",
    "doe'n'tt": "does not",
    "p.s.": "post scriptum"
}
# Out:
# ("r's", 170) contexts:  ["or new year's eve. i", "umid summer's day   ", "e alst year's versio"]
# ("e's", 83) contexts:  ["y valentine's dinner", "f round one's neck &", "d, this one's going "]
# ("n's", 57) contexts:  [" be a woman's white ", "this season's dresse", "ns that won's slide "]
# ("l's", 52) contexts:  ["s the model's photos", "e the model's black ", "s the model's photos"]
# ("d's", 43) contexts:  ["or a friend's spring", " who on god's green ", " my husband's size x"]
# ("t's", 38) contexts:  ["e dress fit's tts (f", " color. lot's of com", "n awesome t'shirt an"]
# ("y's", 27) contexts:  [" than today's peasan", "s or skinny's undern", "ny of today's low-ri"]
# ('i.e', 24) contexts:  [' chested (i.e., you ', 'aterials (i.e. not f', 'designer (i.e.: a li']
# ("d't", 23) contexts:  ["end, i dind't keep t", "eat. i dind't find t", "r and i did't realiz"]
# ("o's", 17) contexts:  ["s on anthto's facebo", "love pilcro's jeans.", " for preggo's! this "]
# ("i's", 15) contexts:  [" strap cami's in nav", "thanks cami's these ", "ign, a cami's would "]
# ("a's", 14) contexts:  ["tyling idea's are en", "cks barista's apron!", " in grandma's table "]
# ("g's", 10) contexts:  ["he building's heat b", "tch. my dog's claw p", "my other ag's Love a"]
# ("j's", 10) contexts:  ["els like pj's. also ", "ing cozy pj's but wi", " Perfect pj's!   I b"]
# ('t.la', 9) contexts:  ['medium in t.la tops.', 'ave other t.la tops ', "orward to t.la's tan"]
# ("s's", 8) contexts:  ["y out of xs's) Throw", " each dress's color ", "n the dress's fit. t"]
# ("m's", 6) contexts:  [" for my mom's birthd", "ding my mom's closet", "from an arm's length"]
# ('p.s', 6) contexts:  ['erneath). p.s. the r', 'etty top. p.s. this ', 'mmer! and p.s. per a']
# ("p's", 5) contexts:  [" most of ap's tops i", "t  This top's subtle", "to, the top's colors"]
# ("n't", 5) contexts:  ["aaaaandidon'twanttop", "return. din't have t", " this doe'n'tt come "]
# ("c's", 5) contexts:  [" the fabric's nice a", "hite fabric's crisp ", "inen fabric's lightw"]
# ("w's", 5) contexts:  ["hter in law's birthd", "et. sparrow's jacket", "o my nephew's birthd"]
# ('top.the', 5) contexts:  ['wy at the top.the pi', 'the whole top.the em', 'better on top.the si']
# ('T.la', 4) contexts:  ["blue one. T.la's cut", ' top ever T.la got i', ' bit long T.la has a']
# ("k's", 3) contexts:  ["t. the back's closur", " st patrick's day pa", "s this tank's regula"]
# ('too.i', 3) contexts:  ['f hemline too.i did ', 'the color too.i am u', 't is good too.i thin']
# ("d'o", 3) contexts:  ["h a black d'orsay fl", " and grey d'orsay he", "to the good'old blac"]
# ("n'd", 2) contexts:  ["enough, din'dt notic", "ve superman'd out if"]
# ('picture.the', 2) contexts:  ['fy in the picture.th', 'es in the picture.th']
# ("e'n", 2) contexts:  ["ut this doe'n'tt com", "5 ft. there'no petit"]

# %%
class text_processing:
  def __init__(self, textseries):
    self.textseries = textseries
    self.processed_text = None
    self.processed_tokens = None
    self.procedures = {1: self.clear_text, 2: self.expand_abbreviations, 3:self.pos_tagging, 4:self.tokenize_text}

  def _procedure(num):
      def wrapper(func):
          func.__procedure__ = num
          return func
      return wrapper

  @_procedure(1)
  def clear_text(self): #clear text and delete stop words
    text = self.processed_text
    text = re.sub(r'[^\w\s]', ' ', text)  # replace all non-alphabet-digital-space symbols on space
    text = text.lower() #place symbols in low register
    text = text.strip() #delete useless spaces
    stop_words = set(stopwords.words('english')) #form set of stopwords
    tokens = [word for word in text.split() if word not in stop_words] #clear from stop words
    self.processed_text = ' '.join(tokens)

  @_procedure(2) #expand abbreviations
  def expand_abbreviations(self):
    text = self.processed_text
    tokens = text.split(sep=' ')
    tokens = [abbreviations_dict.get(word, word) for word in tokens]
    text = ' '.join(tokens)
    self.processed_text = text
    self.processed_tokens = tokens

  @_procedure(3) #apply PoS tagging
  def pos_tagging(self):
    info_tokens = pos_tag(self.processed_tokens)
    self.processed_tokens = [word for word, pos in info_tokens if pos in ['NN', 'JJ', 'RB']]

  @_procedure(4) #tokemize and normalize
  def tokenize_text(self):
    tokens = self.processed_tokens
    # tokens = nltk.word_tokenize(text) #obtain whole list of words
    lemmatizer = WordNetLemmatizer()
    stemmer = SnowballStemmer("english")
    tokens = [stemmer.stem(token) for token in tokens]
    tokens = [lemmatizer.lemmatize(token) for token in tokens] #get list of normalized tokens
    self.processed_tokens = tokens

  def remove_rare_words(self, packed_tokens, all_tokens, freq=5): #delete rare tokens

    token_counts = Counter(all_tokens)
    return [[word for word in tokenlist if token_counts[word] >= freq] for tokenlist in packed_tokens]

  def process_sample(self, sample, code='1234'):
      self.processed_text = str(sample)  # Преобразовать входные данные в строку
      for proc in code:
          self.procedures[int(proc)]()
      return self.processed_tokens

  def process_series(self, freq=5, code='1234'):
      packed_tokens = []
      all_tokens = []
      for sample in tqdm(self.textseries):
          sample_tokens = self.process_sample(sample)
          packed_tokens.append(sample_tokens)
          all_tokens.extend(sample_tokens)
      return self.remove_rare_words(packed_tokens, all_tokens, freq=freq)


df_processed['tokenized_text'] = text_processing(df_processed['combined_text']).process_series()
df_processed['tokenized_text'] = df_processed['tokenized_text'].apply(lambda x: x if (x and len(x[0]) > 0) else None)
df_processed = df_processed.dropna(subset=['tokenized_text'])

def convert_features_to_text(df, processing_field, features):
    text = df[processing_field].apply(lambda x: ' '.join(x))
    for col in features:
        text += ' ' + col + ':' + df[col].astype(str) + ' '
    return text
df_processed['concatenated_text_info'] = convert_features_to_text(df = df_processed, processing_field = 'tokenized_text', features = numerical_features_list+categorical_features_list)
# Out:
# 100%|██████████| 23486/23486 [01:28<00:00, 264.88it/s]
# <ipython-input-11-f3a9a61f4cd7>:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_processed['concatenated_text_info'] = convert_features_to_text(df = df_processed, processing_field = 'tokenized_text', features = numerical_features_list+categorical_features_list)

# %%
df_processed.head(3)
# Out:
#    customer_age  review_rating  positive_feedback_count  product_division  \
# 0      0.222222       0.333333                 0.000000                 3
# 1      0.250000       1.000000                 0.814815                 1
# 2      0.888889       0.166667                 0.000000                 1
#
#    product_department  product_class  not_recommended  \
# 0                   3              6                0
# 1                   2              4                0
# 2                   2              4                1
#
#                                        combined_text  \
# 0  Absolutely wonderful - silky and sexy and comf...
# 1  Love this dress!  it is sooo pretty.  i happen...
# 2  I had such high hopes for this dress and reall...
#
#                                       tokenized_text  \
# 0            [absolut, wonder, silki, sexi, comfort]
# 1  [dress, sooo, pretti, find, store, glad, never...
# 2  [high, realli, want, work, initi, petit, small...
#
#                               concatenated_text_info
# 0  absolut wonder silki sexi comfort customer_age...
# 1  dress sooo pretti find store glad never onlin ...
# 2  high realli want work initi petit small usual ...

# %% [markdown]
# ### 5. Deep Learning and BERT Models for Sentiment Classification (15 pts)
# - **PyTorch LSTM-GRU Model (7.5 pts)**
#     - Tokenization, sequencing, and padding (1.5 pt)
#     - Train-test split (1 pt)
#     - Define and train LSTM-GRU Model (3.5 pts)
#     - Model evaluation (1.5 pt)

# %% [markdown]
# - **Transformers BERT Model using PyTorch (7.5 pts)**
#     - Train-test split (1 pt)
#     - Define tokenizer and apply tokenization and sequencing (1.5 pt)
#     - Transform text to tensor and padding (1.5 pt)
#     - Define and train BERT Model using PyTorch (2.5 pts)
#     - Model evaluation (1 pt)

# %%
#In this task we have categorical, numerical and text features. There is 2 different approaches how to process it.
#1 approach - tokenize text data and after combine it with numerical and text data - it was choosen
#2 approach - combine different types of features all together and after that process this whole text

# Process text data to tensor
texts = df_processed['tokenized_text'].values

# Function to generate tokens from Series of list of tokens
def generate_tokens(textdata):
    for tokenlist in textdata: #iterate series
      for token in tokenlist: #iterate list
        yield token #get token

# Create the vocabulary
vocab = build_vocab_from_iterator(generate_tokens(texts), specials=["<unk>"])
vocab.set_default_index(vocab["<unk>"])

# Convert text data to tensors and add padding
text_tensor = [torch.tensor([vocab[token] for token in text], dtype=torch.long) for text in texts]  # Convert texts to tensors
padded_sequences = pad_sequence(text_tensor, batch_first=True, padding_value=vocab['<pad>'])  # Add padding to the sequences

#Tranform numerical, categorical and labels to tensors
numbers = torch.tensor(df_processed[numerical_features_list].values, dtype=torch.float32)
categories = torch.tensor(df_processed[categorical_features_list].values, dtype=torch.long)
labels = torch.tensor(df_processed['not_recommended'].values, dtype=torch.long)

# Split all data
X_text_train, X_text_val, y_text_train, y_text_val = train_test_split(padded_sequences, labels, test_size=0.2, random_state=42)
X_cat_train, X_cat_val, y_cat_train, y_cat_val = train_test_split(categories, labels, test_size=0.2, random_state=42)
X_num_train, X_num_val, y_num_train, y_num_val = train_test_split(numbers, labels, test_size=0.2, random_state=42)
#Make sure that all indices are equal
assert ((y_text_train == y_cat_train) & (y_cat_train == y_num_train)).all()

#Get test datasets
mask = labels == 1
y_test, X_text_test, X_num_test, X_cat_test = [tensor[mask] for tensor in [labels, padded_sequences, numbers, categories]]

#Prepare loaders
train_loader = DataLoader(TensorDataset(X_text_train, X_cat_train, X_num_train, y_text_train), batch_size=64, shuffle=True)
val_loader = DataLoader(TensorDataset(X_text_val, X_cat_val, X_num_val, y_text_val), batch_size=64, shuffle=False)
test_loader = DataLoader(TensorDataset(X_text_test, X_cat_test, X_num_test, y_test), batch_size=64, shuffle=False)

# %%
def get_accuracy(outputs, labels):
    _, predicted = torch.max(outputs, dim=1)
    true_labels = (predicted == labels).sum().item()
    return true_labels/len(labels)

def train_epoch(model, train_loader, optimizer, loss_fn, device, scheduler, use_attention_mask=False, attention_mask=None):
    model.train()
    avg_loss = 0.0
    avg_acc = 0.0
    for inputs in train_loader:
        if use_attention_mask:
            text_inputs, numerical_inputs, categorical_inputs, labels, attention_mask = inputs
        else:
            text_inputs, numerical_inputs, categorical_inputs, labels = inputs
        text_inputs, numerical_inputs = text_inputs.to(device), numerical_inputs.to(device).float()
        categorical_inputs, labels = categorical_inputs.to(device).float(), labels.to(device)
        optimizer.zero_grad()
        if use_attention_mask: outputs = model(text_inputs, numerical_inputs, categorical_inputs, attention_mask)
        else: outputs = model(text_inputs, numerical_inputs, categorical_inputs)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optimizer.step()
        avg_loss += loss.item()
        avg_acc += get_accuracy(outputs, labels)
    avg_loss /= len(train_loader)
    avg_acc /= len(train_loader)

    if scheduler is not None:
        scheduler.step(avg_loss)

    return avg_loss, avg_acc

def val_epoch(model, val_loader, loss_fn, device, get_metrics=False, use_attention_mask=False, attention_mask=None):
    model.eval()
    avg_loss = 0.0
    avg_acc = 0.0
    all_labels = []
    all_preds = []

    with torch.no_grad():
        for inputs in val_loader:
            if use_attention_mask:
                text_inputs, numerical_inputs, categorical_inputs, labels, attention_mask = inputs
            else:
                text_inputs, numerical_inputs, categorical_inputs, labels = inputs
            text_inputs, numerical_inputs = text_inputs.to(device), numerical_inputs.to(device).float()
            categorical_inputs, labels = categorical_inputs.to(device).float(), labels.to(device)
            if use_attention_mask: outputs = model(text_inputs, numerical_inputs, categorical_inputs, attention_mask)
            else: outputs = model(text_inputs, numerical_inputs, categorical_inputs)
            loss = loss_fn(outputs, labels)
            avg_loss += loss.item()
            avg_acc += get_accuracy(outputs, labels)

            _, preds = torch.max(outputs, dim=1)
            all_labels += labels.cpu().tolist()
            all_preds += preds.cpu().tolist()


    avg_loss /= len(val_loader)
    avg_acc /= len(val_loader)
    if get_metrics:
        f1 = f1_score(all_labels, all_preds, average='macro')
        recall = recall_score(all_labels, all_preds, average='macro', zero_division=1)
        avg_precision = average_precision_score(all_labels, all_preds, average='macro')
        return avg_loss, avg_acc, f1, recall, avg_precision

    return avg_loss, avg_acc

# %%
class LSTMGRUModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, num_layers, num_features, cat_features, output_dim, dropout):
        super().__init__()
        self.num_features = num_features
        self.cat_features = cat_features
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.embedding_norm = nn.LayerNorm(embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, num_layers, dropout=dropout, batch_first=True)
        self.gru = nn.GRU(hidden_dim, hidden_dim, num_layers, dropout=dropout, batch_first=True)
        self.fc_text = nn.Linear(hidden_dim, hidden_dim)
        self.fc_text_norm = nn.LayerNorm(hidden_dim)
        self.fc_num = nn.Linear(num_features, hidden_dim)
        self.fc_num_norm = nn.LayerNorm(hidden_dim)
        self.fc_cat = nn.Linear(cat_features, hidden_dim)
        self.fc_cat_norm = nn.LayerNorm(hidden_dim)
        self.fc_out = nn.Linear(hidden_dim * 3, output_dim)
        self.sigmoid = nn.Sigmoid()
        self.dropout = nn.Dropout(dropout)

    def forward(self, text_inputs, numerical_inputs, categorical_inputs):
        embedded = self.embedding(text_inputs)
        embedded = self.embedding_norm(embedded)
        lstm_out, _ = self.lstm(embedded)
        gru_out, _ = self.gru(lstm_out)
        output_text = self.dropout(self.fc_text_norm(self.fc_text(gru_out)))
        output_num = self.dropout(self.fc_num_norm(self.fc_num(numerical_inputs)))
        output_cat = self.dropout(self.fc_cat_norm(self.fc_cat(categorical_inputs)))
        output_text = output_text[:, -1, :]  # From (batch_size, sequence_length, hidden_size) to (batch_size, hidden_size). Last hidden state
        output = torch.cat((output_text, output_num, output_cat), dim=1)
        output = self.fc_out(output)
        output = self.sigmoid(output)
        return output

# %%
# Set hyperparameters
vocab_size = len(vocab)
embedding_dim = 128
hidden_dim = 128
num_layers = 5
num_features = len(numerical_features_list)
cat_features = len(categorical_features_list)
output_dim = 2
dropout = 0.2

# Initialize the model, loss function, and optimizer
model = LSTMGRUModel(vocab_size, embedding_dim, hidden_dim, num_layers, num_features, cat_features, output_dim, dropout).to(device)
loss_fn = nn.CrossEntropyLoss(weight=class_weights_tensor)
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode = 'min')

# %%
# Train the model
num_epochs = 10
early_stopping = 5
best_val_acc = 0.0

for epoch in range(num_epochs):
  print(f"Epoch {epoch}")
  train_loss, train_acc = train_epoch(model, train_loader, optimizer, loss_fn, device=device, scheduler=scheduler)
  print(f"Train loss {train_loss:.3f}. Train acc {train_acc:.3f}")
  val_loss, val_acc = val_epoch(model, val_loader, loss_fn, device=device)
  if val_acc > best_val_acc:
    best_val_acc = val_acc
    stop_iter = 0
    torch.save(model.state_dict(), 'best_model_LSTM_sep.pt')
  else:
    stop_iter += 1
  print(f"Val loss {val_loss:.3f}. Val acc {val_acc:.3f}. Best val acc = {best_val_acc:.3f}")

val_loss, val_acc, val_f1, val_recall, val_avg_precision = val_epoch(model, val_loader, loss_fn, device, get_metrics=True)
test_loss, test_acc, test_f1, test_recall, test_avg_precision = val_epoch(model, test_loader, loss_fn, device, get_metrics=True)
LSTM_metrics = [test_loss, test_acc, test_f1, test_recall, test_avg_precision]
print(f"Val loss: {val_loss:.3f}, Val acc: {val_acc:.3f}, Val F1: {val_f1:.3f}, Val Recall: {val_recall:.3f}, Val Avg Precision: {val_avg_precision:.3f}")
print(f"Test loss: {test_loss:.3f}, Test acc: {test_acc:.3f}, Test F1: {test_f1:.3f}, Test Recall: {test_recall:.3f}, Test Avg Precision: {test_avg_precision:.3f}")
# Out:
# Epoch 0
# Train loss 0.457. Train acc 0.858
# Val loss 0.390. Val acc 0.932. Best val acc = 0.932
# Epoch 1
# Train loss 0.376. Train acc 0.938
# Val loss 0.376. Val acc 0.932. Best val acc = 0.932
# Epoch 2
# Train loss 0.371. Train acc 0.938
# Val loss 0.375. Val acc 0.932. Best val acc = 0.932
# Epoch 3
# Train loss 0.370. Train acc 0.938
# Val loss 0.374. Val acc 0.932. Best val acc = 0.932
# Epoch 4
# Train loss 0.369. Train acc 0.938
# Val loss 0.374. Val acc 0.932. Best val acc = 0.932
# Epoch 5
# Train loss 0.369. Train acc 0.938
# Val loss 0.374. Val acc 0.932. Best val acc = 0.932
# Epoch 6
# Train loss 0.370. Train acc 0.938
# Val loss 0.374. Val acc 0.932. Best val acc = 0.932
# Epoch 7
# Train loss 0.369. Train acc 0.938
# Val loss 0.374. Val acc 0.932. Best val acc = 0.932
# Epoch 8
# Train loss 0.369. Train acc 0.938
# Val loss 0.374. Val acc 0.932. Best val acc = 0.932
# Epoch 9
# Train loss 0.369. Train acc 0.938
# Val loss 0.374. Val acc 0.932. Best val acc = 0.932
# Val loss: 0.374, Val acc: 0.932, Val F1: 0.895, Val Recall: 0.939, Val Avg Precision: 0.715
# Test loss: 0.360, Test acc: 0.953, Test F1: 0.488, Test Recall: 0.977, Test Avg Precision: 1.000

# %%
LSTM_metrics_dict = {
    'test_loss': test_loss,
    'test_acc': test_acc,
    'test_f1': test_f1,
    'test_recall': test_recall,
    'test_avg_precision': test_avg_precision
}
results_dict = {
    'LSTM_metrics_dict': LSTM_metrics_dict
}
with open('results.json', 'w') as f:
    json.dump(results_dict, f, indent=4)

# Reading JSON
with open('results.json', 'r') as f:
    loaded_results = json.load(f)

print(loaded_results)
# Out:
# {'first_LSTM_metrics_dict': {'test_loss': 0.3599729054805004, 'test_acc': 0.9532828282828283, 'test_f1': 0.4881609618451724, 'test_recall': 0.9768696069031639, 'test_avg_precision': 1.0}}

# %%
my_token = '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'

max_len = 256

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

config = BertConfig.from_pretrained('bert-base-uncased')

hidden_size = config.hidden_size

def encode(text, tokenizer, max_len):
    encoded_dict = tokenizer.encode_plus(
        text,
        add_special_tokens=True,
        max_length=max_len,
        padding='max_length',
        truncation=True,
        return_attention_mask=True,
        return_tensors='pt',
    )
    input_ids = encoded_dict['input_ids']
    attention_mask = encoded_dict['attention_mask']


    return input_ids, attention_mask

text_inputs, attention_mask = zip(*[encode(text, tokenizer, 46) for text in texts])
text_inputs = torch.cat(text_inputs, dim=0).to(device)
attention_mask = torch.cat(attention_mask, dim=0).to(device)

attention_mask_train, attention_mask_val, _, _ = train_test_split(attention_mask, labels, test_size=0.2, random_state=42)
attention_mask_test = attention_mask[mask]

train_dataset_BERT = TensorDataset(X_text_train, X_cat_train, X_num_train, y_text_train, attention_mask_train)
val_dataset_BERT = TensorDataset(X_text_val, X_cat_val, X_num_val, y_text_val, attention_mask_val)
test_dataset_BERT = TensorDataset(X_text_test, X_cat_test, X_num_test, y_test, attention_mask_test)

train_loader_BERT = DataLoader(train_dataset_BERT, batch_size=64, shuffle=True)
val_loader_BERT = DataLoader(val_dataset_BERT, batch_size=64, shuffle=False)
test_loader_BERT = DataLoader(test_dataset_BERT, batch_size=64, shuffle=False)

# %%
class BERTModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, num_features, cat_features, output_dim, dropout):
        super().__init__()
        self.num_features = num_features
        self.cat_features = cat_features
        self.bert = BertModel.from_pretrained('bert-base-uncased')
        for param in self.bert.parameters(): param.requires_grad = True
        self.fc_text = nn.Linear(hidden_size, embedding_dim)
        self.fc_text_norm = nn.LayerNorm(embedding_dim)
        self.fc_num = nn.Linear(num_features, embedding_dim)
        self.fc_num_norm = nn.LayerNorm(embedding_dim)
        self.fc_cat = nn.Linear(cat_features, embedding_dim)
        self.fc_cat_norm = nn.LayerNorm(embedding_dim)
        self.fc_out = nn.Linear(embedding_dim * 3, output_dim)
        self.sigmoid = nn.Sigmoid()
        self.dropout = nn.Dropout(dropout)

    def forward(self, text_inputs, numerical_inputs, categorical_inputs, attention_mask):
        embedded = self.bert(text_inputs, attention_mask=attention_mask)[0]
        embedded = self.fc_text(embedded)
        embedded = embedded.mean(dim=1).view(-1, embedding_dim)
        output_text = self.fc_text_norm(self.dropout(embedded))
        output_num = self.fc_num_norm(self.dropout(self.fc_num(numerical_inputs)))
        output_cat = self.fc_cat_norm(self.dropout(self.fc_cat(categorical_inputs)))
        output = torch.cat((output_text, output_num, output_cat), dim=1)
        output = self.fc_out(output)
        output = self.sigmoid(output)
        return output

# %%
#Choose parameters
vocab_size = len(vocab)
embedding_dim = 64
num_features = len(numerical_features_list)
cat_features = len(categorical_features_list)
output_dim = 2
dropout = 0.2
# Train the model
model = BERTModel(vocab_size, embedding_dim, num_features, cat_features, output_dim, dropout).to(device)
loss_fn = nn.CrossEntropyLoss(weight=class_weights_tensor)
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode = 'min')
num_epochs = 5
early_stopping = 3
best_val_acc = 0.0

for epoch in range(num_epochs):
  print(f"Epoch {epoch}")
  train_loss, train_acc = train_epoch(model, train_loader_BERT, optimizer, loss_fn, device=device, scheduler=scheduler, use_attention_mask=True, attention_mask=attention_mask_train)
  print(f"Train loss {train_loss:.3f}. Train acc {train_acc:.3f}")
  val_loss, val_acc = val_epoch(model, val_loader_BERT, loss_fn, device=device, use_attention_mask=True, attention_mask=attention_mask_val)
  if val_acc > best_val_acc:
    best_val_acc = val_acc
    stop_iter = 0
    torch.save(model.state_dict(), 'best_model_BERT_sep.pt')
  else:
    stop_iter += 1
  print(f"Val loss {val_loss:.3f}. Val acc {val_acc:.3f}. Best val acc = {best_val_acc:.3f}")

val_loss, val_acc, val_f1, val_recall, val_avg_precision = val_epoch(model, val_loader_BERT, loss_fn, device, get_metrics=True, use_attention_mask=True, attention_mask=attention_mask_val)
test_loss, test_acc, test_f1, test_recall, test_avg_precision = val_epoch(model, test_loader_BERT, loss_fn, device, get_metrics=True, use_attention_mask=True, attention_mask=attention_mask_test)
BERT_metrics = [test_loss, test_acc, test_f1, test_recall, test_avg_precision]
print(f"Val loss: {val_loss:.3f}, Val acc: {val_acc:.3f}, Val F1: {val_f1:.3f}, Val Recall: {val_recall:.3f}, Val Avg Precision: {val_avg_precision:.3f}")
print(f"Test loss: {test_loss:.3f}, Test acc: {test_acc:.3f}, Test F1: {test_f1:.3f}, Test Recall: {test_recall:.3f}, Test Avg Precision: {test_avg_precision:.3f}")
# Out:
# Epoch 0
# Train loss 0.477. Train acc 0.829
# Val loss 0.386. Val acc 0.936. Best val acc = 0.936
# Epoch 1
# Train loss 0.381. Train acc 0.934
# Val loss 0.368. Val acc 0.936. Best val acc = 0.936
# Epoch 2
# Train loss 0.374. Train acc 0.935
# Val loss 0.367. Val acc 0.936. Best val acc = 0.936
# Epoch 3
# Train loss 0.372. Train acc 0.935
# Val loss 0.366. Val acc 0.936. Best val acc = 0.936
# Epoch 4
# Train loss 0.372. Train acc 0.935
# Val loss 0.366. Val acc 0.936. Best val acc = 0.936
# Val loss: 0.366, Val acc: 0.936, Val F1: 0.901, Val Recall: 0.947, Val Avg Precision: 0.727
# Test loss: 0.358, Test acc: 0.955, Test F1: 0.488, Test Recall: 0.977, Test Avg Precision: 1.000

# %% [markdown]
# ### 6. Compare Models (3 pts)
# - **Accuracy Scores, F1 Scores, Recall Scores, and Average Precision Score (3 pts)**: Compare the performance of LSTM-GRU and BERT models across these metrics.

# %% [markdown]
# ### 7. Predict Test Data (2 pts)
# - **All Unrecommended Reviews (2 pts)**: Use the trained models to predict sentiment on the dataset of unrecommended reviews.

# %%
BERT_metrics_dict = {
    'test_loss': test_loss,
    'test_acc': test_acc,
    'test_f1': test_f1,
    'test_recall': test_recall,
    'test_avg_precision': test_avg_precision
}

with open('results.json', 'r') as file:
    results = json.load(file)

results['BERT_metrics_dict'] = BERT_metrics_dict

with open('results.json', 'w') as file:
    json.dump(results, file)

with open('results.json', 'r') as file:
    results = json.load(file)

lstm_metrics_df = pd.DataFrame.from_dict(results['LSTM_metrics_dict'], orient='index').reset_index().rename(columns={'index': 'metric', 0: 'value'})
lstm_metrics_df['model'] = 'LSTM'

bert_metrics_df = pd.DataFrame.from_dict(results['BERT_metrics_dict'], orient='index').reset_index().rename(columns={'index': 'metric', 0: 'value'})
bert_metrics_df['model'] = 'BERT'

metrics_df = pd.concat([lstm_metrics_df, bert_metrics_df])

print(metrics_df)
# Out:
#                metric     value model
# 0           test_loss  0.359973  LSTM
# 1            test_acc  0.953283  LSTM
# 2             test_f1  0.488161  LSTM
# 3         test_recall  0.976870  LSTM
# 4  test_avg_precision  1.000000  LSTM
# 0           test_loss  0.358428  BERT
# 1            test_acc  0.955048  BERT
# 2             test_f1  0.488334  BERT
# 3         test_recall  0.977201  BERT
# 4  test_avg_precision  1.000000  BERT

# %% [markdown]
# ## Problem 2. Natural language generation (35 pts)
#
# This problem requires uploading two csv files along with the solution notebook. Please compress these three files in zip archive and upload it in Canvas.
#
# Natural language generation (NLG) is a well-known research problem concerned with generating textual descriptions of structured data, such as tables, as output. Compared to machine translation, where the goal is to completely convert an input sentence into another language, NLG requires overcoming two different challenges: deciding what to say, by selecting a relevant subset of the input data to describe, and deciding how to say it, by generating text that flows and reads naturally.
#
# In this task you will need to generate table descriptions and titles for the dataset that can be downloaded from lms canvas folder "dataset/dataset_nlg.zip". Your inference pipeline should receive `.csv` and output 2 strings: table description `text` and table title `title`.
#
# As the solution to this task you shoud complete `submission.csv` and `submission_reranking.csv` files as below and report the link on your finetuned checkpoints.

# %%
import numpy as np
import pandas as pd
import torch
# !pip install rouge-score
# !pip install sacrebleu
# !pip install bert-score
from tqdm import tqdm
from transformers import T5ForConditionalGeneration, T5Tokenizer
from sklearn.model_selection import train_test_split
import nltk
# from sacrebleu.metrics import BLEU
from nltk.translate.meteor_score import meteor_score
from bert_score import score
from rouge_score import rouge_scorer
from transformers import BertTokenizer, BertModel

from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from nltk.translate.meteor_score import single_meteor_score
import torch.optim as optim

import torch.nn as nn
import torch.nn.functional as F

device = ("cuda" if torch.cuda.is_available() else "cpu")

# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')
# nltk.download('wordnet')
# nltk.download('omw')
# Out:
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.25.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (4.66.2)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=8b0bebeb4466923d56108002c4f769c7a1bf3dd6d9e40b5571f7104112498593
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2
# Collecting sacrebleu
#   Downloading sacrebleu-2.4.2-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 3.9 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (1.25.2)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (4.9.4)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 portalocker-2.8.2 sacrebleu-2.4.2
# Collecting bert-score
#   Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.2.1+cu121)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.0.3)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert-score) (4.40.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert-score) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.31.0)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert-score) (4.66.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert-score) (3.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert-score) (24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2024.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.0.0->bert-score)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.0.0->bert-score)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.0.0->bert-score)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.0.0->bert-score)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.0.0->bert-score)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.0.0->bert-score)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.0.0->bert-score)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.0.0->bert-score)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.0.0->bert-score)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.0.0->bert-score)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.0.0->bert-score)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.0.0->bert-score)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.20.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (2023.12.25)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.4.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert-score) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert-score) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0.0->bert-score) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bert-score
# Successfully installed bert-score-0.3.13 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105

# %%
# !unzip '/content/drive/MyDrive/Deep Learning/HW/Datasets/dataset_nlg.zip'
dataset_path = '/content/dataset_nlg'
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   inflating: dataset_nlg_v1/data/223685202396115.csv
#   inflating: dataset_nlg_v1/data/1903008436452839588.csv
#   inflating: dataset_nlg_v1/data/17849348756475776434.csv
#   inflating: dataset_nlg_v1/data/223685202391810.csv
#   inflating: dataset_nlg_v1/data/13052822949931163071.csv
#   inflating: dataset_nlg_v1/data/3752806015948410158.csv
#   inflating: dataset_nlg_v1/data/3685863684819740294.csv
#   inflating: dataset_nlg_v1/data/7537359542959669888.csv
#   inflating: dataset_nlg_v1/data/14222033772740785160.csv
#   inflating: dataset_nlg_v1/data/1778422877764209398.csv
#   inflating: dataset_nlg_v1/data/7347000480692584125.csv
#   inflating: dataset_nlg_v1/data/11655774884564649005.csv
#   inflating: dataset_nlg_v1/data/17191328118726412715.csv
#   inflating: dataset_nlg_v1/data/223685202387825.csv
#   inflating: dataset_nlg_v1/data/15590756896164817683.csv
#   inflating: dataset_nlg_v1/data/223685202388653.csv
#   inflating: dataset_nlg_v1/data/1704637378270850932.csv
#   inflating: dataset_nlg_v1/data/223685202388121.csv
#   inflating: dataset_nlg_v1/data/3903715238454240066.csv
#   inflating: dataset_nlg_v1/data/13177122091927427265.csv
#   inflating: dataset_nlg_v1/data/15813702618868692003.csv
#   inflating: dataset_nlg_v1/data/9320667251233144832.csv
#   inflating: dataset_nlg_v1/data/223685202392056.csv
#   inflating: dataset_nlg_v1/data/223685202387339.csv
#   inflating: dataset_nlg_v1/data/14478172175149034249.csv
#   inflating: dataset_nlg_v1/data/17516154246203945188.csv
#  extracting: dataset_nlg_v1/data/7883264127316033672.csv
#   inflating: dataset_nlg_v1/data/11779732663105840426.csv
#   inflating: dataset_nlg_v1/data/15345671566477958287.csv
#   inflating: dataset_nlg_v1/data/12036007767125635088.csv
#   inflating: dataset_nlg_v1/data/7574903429834037487.csv
#   inflating: dataset_nlg_v1/data/223685202386583.csv
#   inflating: dataset_nlg_v1/data/11765671535923508390.csv
#   inflating: dataset_nlg_v1/data/223685202389741.csv
#   inflating: dataset_nlg_v1/data/9926700352873426004.csv
#   inflating: dataset_nlg_v1/data/17298339819331289030.csv
#   inflating: dataset_nlg_v1/data/15308572877073028568.csv
#   inflating: dataset_nlg_v1/data/5696396898918356827.csv
#   inflating: dataset_nlg_v1/data/7461747336565404887.csv
#   inflating: dataset_nlg_v1/data/18058462245216480581.csv
#   inflating: dataset_nlg_v1/data/223685202389319.csv
#   inflating: dataset_nlg_v1/data/223685202385892.csv
#   inflating: dataset_nlg_v1/data/3267673347259388755.csv
#   inflating: dataset_nlg_v1/data/223685202388570.csv
#   inflating: dataset_nlg_v1/data/6812422519770960560.csv
#   inflating: dataset_nlg_v1/data/1246653520022296353.csv
#   inflating: dataset_nlg_v1/data/223685202388042.csv
#   inflating: dataset_nlg_v1/data/16133891595052097889.csv
#   inflating: dataset_nlg_v1/data/3531779546493090563.csv
#   inflating: dataset_nlg_v1/data/9674454036464811806.csv
#   inflating: dataset_nlg_v1/data/11401201771301970238.csv
#   inflating: dataset_nlg_v1/data/14247963145040788385.csv
#   inflating: dataset_nlg_v1/data/4104651188943266600.csv
#   inflating: dataset_nlg_v1/data/11912391362858255524.csv
#   inflating: dataset_nlg_v1/data/223685202394984.csv
#   inflating: dataset_nlg_v1/data/1747709528875001595.csv
#   inflating: dataset_nlg_v1/data/9409327609253311369.csv
#   inflating: dataset_nlg_v1/data/2865337402879760465.csv
#   inflating: dataset_nlg_v1/data/223685202391302.csv
#   inflating: dataset_nlg_v1/data/6242436673673672592.csv
#   inflating: dataset_nlg_v1/data/5402558234269827080.csv
#   inflating: dataset_nlg_v1/data/223685202393174.csv
#   inflating: dataset_nlg_v1/data/11772890316509456963.csv
#   inflating: dataset_nlg_v1/data/11073034534511155142.csv
#   inflating: dataset_nlg_v1/data/7577582274265754447.csv
#   inflating: dataset_nlg_v1/data/223685202391211.csv
#   inflating: dataset_nlg_v1/data/223685202391182.csv
#   inflating: dataset_nlg_v1/data/9314682713393826859.csv
#  extracting: dataset_nlg_v1/data/16551062260892633579.csv
#   inflating: dataset_nlg_v1/data/223685202390623.csv
#   inflating: dataset_nlg_v1/data/15747177463928735179.csv
#   inflating: dataset_nlg_v1/data/18184843573076125161.csv
#   inflating: dataset_nlg_v1/data/4236487558955734585.csv
#   inflating: dataset_nlg_v1/data/14662845693983960926.csv
#   inflating: dataset_nlg_v1/data/10230441118762418553.csv
#   inflating: dataset_nlg_v1/data/618206566836063356.csv
#   inflating: dataset_nlg_v1/data/11646116514950355742.csv
#   inflating: dataset_nlg_v1/data/15850526001610891118.csv
#   inflating: dataset_nlg_v1/data/223685202395095.csv
#   inflating: dataset_nlg_v1/data/223685202394771.csv
#   inflating: dataset_nlg_v1/data/223685202393242.csv
#   inflating: dataset_nlg_v1/data/3000772520074425225.csv
#   inflating: dataset_nlg_v1/data/9338291184153667910.csv
#   inflating: dataset_nlg_v1/data/13178429192545945371.csv
#   inflating: dataset_nlg_v1/data/5935003725343365152.csv
#   inflating: dataset_nlg_v1/data/223685202394253.csv
#   inflating: dataset_nlg_v1/data/6288606711873232656.csv
#   inflating: dataset_nlg_v1/data/223685202392288.csv
#   inflating: dataset_nlg_v1/data/5633287498544970918.csv
#   inflating: dataset_nlg_v1/data/8662882389324751317.csv
#   inflating: dataset_nlg_v1/data/10706400457407222524.csv
#   inflating: dataset_nlg_v1/data/223685202390738.csv
#   inflating: dataset_nlg_v1/data/14153500923332759451.csv
#   inflating: dataset_nlg_v1/data/494428750523397569.csv
#   inflating: dataset_nlg_v1/data/10724997471311779325.csv
#   inflating: dataset_nlg_v1/data/13364846902721197378.csv
#   inflating: dataset_nlg_v1/data/12671878853463189271.csv
#   inflating: dataset_nlg_v1/data/8014100209687603773.csv
#   inflating: dataset_nlg_v1/data/223685202391166.csv
#   inflating: dataset_nlg_v1/data/13338981965322965445.csv
#   inflating: dataset_nlg_v1/data/3338427894512665753.csv
#   inflating: dataset_nlg_v1/data/788562396838921622.csv
#   inflating: dataset_nlg_v1/data/223685202393412.csv
#   inflating: dataset_nlg_v1/data/17936044868896700304.csv
#   inflating: dataset_nlg_v1/data/11624849746366849821.csv
#   inflating: dataset_nlg_v1/data/15533005420409921183.csv
#   inflating: dataset_nlg_v1/data/7951284482416578903.csv
#   inflating: dataset_nlg_v1/data/10801565220135152647.csv
#   inflating: dataset_nlg_v1/data/8054837668067629848.csv
#   inflating: dataset_nlg_v1/data/223685202387337.csv
#   inflating: dataset_nlg_v1/data/223685202387089.csv
#   inflating: dataset_nlg_v1/data/223685202395620.csv
#   inflating: dataset_nlg_v1/data/10755049633136510847.csv
#   inflating: dataset_nlg_v1/data/16445356736862070084.csv
#   inflating: dataset_nlg_v1/data/7518399853261029869.csv
#   inflating: dataset_nlg_v1/data/15166360619877879002.csv
#   inflating: dataset_nlg_v1/data/16761198385997301714.csv
#   inflating: dataset_nlg_v1/data/223685202390592.csv
#   inflating: dataset_nlg_v1/data/9583987943433328958.csv
#   inflating: dataset_nlg_v1/data/223685202388401.csv
#   inflating: dataset_nlg_v1/data/15522653944887974949.csv
#   inflating: dataset_nlg_v1/data/11249478211862645375.csv
#   inflating: dataset_nlg_v1/data/10092202903150741920.csv
#   inflating: dataset_nlg_v1/data/10842679465282165857.csv
#   inflating: dataset_nlg_v1/data/223685202389971.csv
#   inflating: dataset_nlg_v1/data/12129927208730188690.csv
#   inflating: dataset_nlg_v1/data/5774859631931738968.csv
#   inflating: dataset_nlg_v1/data/8119792598159235119.csv
#   inflating: dataset_nlg_v1/data/18002879310308413652.csv
#   inflating: dataset_nlg_v1/data/7293423747160098716.csv
#   inflating: dataset_nlg_v1/data/223685202392212.csv
#   inflating: dataset_nlg_v1/data/223685202389865.csv
#   inflating: dataset_nlg_v1/data/10057282612151390464.csv
#   inflating: dataset_nlg_v1/data/223685202387668.csv
#   inflating: dataset_nlg_v1/data/223685202386137.csv
#   inflating: dataset_nlg_v1/data/9604320384275814779.csv
#   inflating: dataset_nlg_v1/data/17400927386875710956.csv
#   inflating: dataset_nlg_v1/data/223685202387702.csv
#   inflating: dataset_nlg_v1/data/5446054060565409867.csv
#   inflating: dataset_nlg_v1/data/223685202394495.csv
#   inflating: dataset_nlg_v1/data/223685202393207.csv
#   inflating: dataset_nlg_v1/data/9819337629120888262.csv
#   inflating: dataset_nlg_v1/data/4027018987425479373.csv
#   inflating: dataset_nlg_v1/data/4702389835110274291.csv
#   inflating: dataset_nlg_v1/data/223685202388881.csv
#   inflating: dataset_nlg_v1/data/343697825866879833.csv
#   inflating: dataset_nlg_v1/data/223685202395849.csv
#   inflating: dataset_nlg_v1/data/223685202390120.csv
#   inflating: dataset_nlg_v1/data/5689329237915507574.csv
#   inflating: dataset_nlg_v1/data/155192109131125914.csv
#   inflating: dataset_nlg_v1/data/17764888422311882330.csv
#   inflating: dataset_nlg_v1/data/902912457596731638.csv
#   inflating: dataset_nlg_v1/data/14959551584979415938.csv
#   inflating: dataset_nlg_v1/data/11104734820900244891.csv
#   inflating: dataset_nlg_v1/data/15377732966860129114.csv
#   inflating: dataset_nlg_v1/data/16485758733287020317.csv
#   inflating: dataset_nlg_v1/data/9972035777736305285.csv
#   inflating: dataset_nlg_v1/data/5397829097848303400.csv
#   inflating: dataset_nlg_v1/data/9208170623489415592.csv
#   inflating: dataset_nlg_v1/data/11935210723771297962.csv
#   inflating: dataset_nlg_v1/data/13334279245878722019.csv
#   inflating: dataset_nlg_v1/data/223685202389970.csv
#   inflating: dataset_nlg_v1/data/17493398560477760748.csv
#   inflating: dataset_nlg_v1/data/351127334494450662.csv
#   inflating: dataset_nlg_v1/data/5609309645445718443.csv
#   inflating: dataset_nlg_v1/data/223685202395470.csv
#   inflating: dataset_nlg_v1/data/4773346507729487386.csv
#   inflating: dataset_nlg_v1/data/10683777991427405477.csv
#   inflating: dataset_nlg_v1/data/2032498600184313096.csv
#   inflating: dataset_nlg_v1/data/9216575981119669875.csv
#   inflating: dataset_nlg_v1/data/16770260969221763860.csv
#   inflating: dataset_nlg_v1/data/5510418681490716431.csv
#   inflating: dataset_nlg_v1/data/5386968024911498534.csv
#   inflating: dataset_nlg_v1/data/223685202389628.csv
#   inflating: dataset_nlg_v1/data/10906548559231757614.csv
#   inflating: dataset_nlg_v1/data/8374925252245398260.csv
#   inflating: dataset_nlg_v1/data/6179999842670643785.csv
#   inflating: dataset_nlg_v1/data/6100159694610940708.csv
#   inflating: dataset_nlg_v1/data/11461008639333212470.csv
#   inflating: dataset_nlg_v1/data/223685202391705.csv
#   inflating: dataset_nlg_v1/data/223685202386038.csv
#   inflating: dataset_nlg_v1/data/223685202389157.csv
#   inflating: dataset_nlg_v1/data/223685202394001.csv
#   inflating: dataset_nlg_v1/data/13717912722879357106.csv
#   inflating: dataset_nlg_v1/data/4028013953338738172.csv
#   inflating: dataset_nlg_v1/data/5513856376515728686.csv
#   inflating: dataset_nlg_v1/data/4776054564118858332.csv
#   inflating: dataset_nlg_v1/data/13127235802047312211.csv
#   inflating: dataset_nlg_v1/data/12799455296535791658.csv
#   inflating: dataset_nlg_v1/data/11122205490184872045.csv
#   inflating: dataset_nlg_v1/data/13361601868395765688.csv
#   inflating: dataset_nlg_v1/data/16980410315831120357.csv
#   inflating: dataset_nlg_v1/data/223685202391529.csv
#   inflating: dataset_nlg_v1/data/6999761162359917214.csv
#  extracting: dataset_nlg_v1/data/14156942638422504137.csv
#   inflating: dataset_nlg_v1/data/11710449726392055298.csv
#   inflating: dataset_nlg_v1/data/180795677666290735.csv
#   inflating: dataset_nlg_v1/data/223685202387372.csv
#   inflating: dataset_nlg_v1/data/11271182360420834392.csv
#   inflating: dataset_nlg_v1/data/286213165592559543.csv
#   inflating: dataset_nlg_v1/data/1090872462750627052.csv
#  extracting: dataset_nlg_v1/data/7611856414876612409.csv
#   inflating: dataset_nlg_v1/data/223685202387534.csv
#   inflating: dataset_nlg_v1/data/15855992732042227338.csv
#   inflating: dataset_nlg_v1/data/11583725563454972436.csv
#   inflating: dataset_nlg_v1/data/9488059594869834433.csv
#   inflating: dataset_nlg_v1/data/10020000031268566160.csv
#   inflating: dataset_nlg_v1/data/3795155445814343817.csv
#   inflating: dataset_nlg_v1/data/9151969877387298293.csv
#   inflating: dataset_nlg_v1/data/4275470749683532491.csv
#   inflating: dataset_nlg_v1/data/3073266222970826555.csv
#   inflating: dataset_nlg_v1/data/6511854178224620915.csv
#   inflating: dataset_nlg_v1/data/15288843066605000746.csv
#   inflating: dataset_nlg_v1/data/14662556893673244928.csv
#  extracting: dataset_nlg_v1/data/223685202388087.csv
#   inflating: dataset_nlg_v1/data/1601714011522277220.csv
#   inflating: dataset_nlg_v1/data/16043395742683998886.csv
#   inflating: dataset_nlg_v1/data/12150645989205237740.csv
#   inflating: dataset_nlg_v1/data/223685202386965.csv
#   inflating: dataset_nlg_v1/data/223685202387357.csv
#   inflating: dataset_nlg_v1/data/223685202395987.csv
#   inflating: dataset_nlg_v1/data/15213521457630250704.csv
#   inflating: dataset_nlg_v1/data/223685202386514.csv
#   inflating: dataset_nlg_v1/data/223685202387589.csv
#   inflating: dataset_nlg_v1/data/873724394803216915.csv
#   inflating: dataset_nlg_v1/data/16182629723252941962.csv
#   inflating: dataset_nlg_v1/data/10138630860920170057.csv
#   inflating: dataset_nlg_v1/data/15488209952226006482.csv
#   inflating: dataset_nlg_v1/data/14819073554141252700.csv
#   inflating: dataset_nlg_v1/data/14593282018726146369.csv
#   inflating: dataset_nlg_v1/data/3655027181705376987.csv
#   inflating: dataset_nlg_v1/data/8753051236000481642.csv
#   inflating: dataset_nlg_v1/data/223685202391794.csv
#   inflating: dataset_nlg_v1/data/223685202388411.csv
#   inflating: dataset_nlg_v1/data/223685202393350.csv
#   inflating: dataset_nlg_v1/data/223685202385774.csv
#   inflating: dataset_nlg_v1/data/223685202394480.csv
#   inflating: dataset_nlg_v1/data/223685202390678.csv
#   inflating: dataset_nlg_v1/data/7570737529095757032.csv
#   inflating: dataset_nlg_v1/data/223685202393208.csv
#   inflating: dataset_nlg_v1/data/10787340406079678731.csv
#   inflating: dataset_nlg_v1/data/5616814284239846572.csv
#   inflating: dataset_nlg_v1/data/10256161419352166330.csv
#   inflating: dataset_nlg_v1/data/2426679453234634048.csv
#   inflating: dataset_nlg_v1/data/3445409204401872662.csv
#   inflating: dataset_nlg_v1/data/14131939672553105818.csv
#   inflating: dataset_nlg_v1/data/223685202389808.csv
#   inflating: dataset_nlg_v1/data/223685202386772.csv
#   inflating: dataset_nlg_v1/data/223685202396392.csv
#   inflating: dataset_nlg_v1/data/14999061367558773770.csv
#   inflating: dataset_nlg_v1/data/9636085498428350211.csv
#   inflating: dataset_nlg_v1/data/223685202396446.csv
#   inflating: dataset_nlg_v1/data/4291505188000049076.csv
#   inflating: dataset_nlg_v1/data/10877962767781713439.csv
#   inflating: dataset_nlg_v1/data/7116038209657406372.csv
#  extracting: dataset_nlg_v1/data/3563918600221810727.csv
#   inflating: dataset_nlg_v1/data/15233999355300902503.csv
#   inflating: dataset_nlg_v1/data/9641558367733320902.csv
#   inflating: dataset_nlg_v1/data/4837070039208173381.csv
#   inflating: dataset_nlg_v1/data/11721641939140974491.csv
#   inflating: dataset_nlg_v1/data/223685202394605.csv
#   inflating: dataset_nlg_v1/data/5451459711163025746.csv
#   inflating: dataset_nlg_v1/data/1274315249516483360.csv
#   inflating: dataset_nlg_v1/data/17878417604738536986.csv
#   inflating: dataset_nlg_v1/data/223685202392366.csv
#   inflating: dataset_nlg_v1/data/11624712888053642966.csv
#   inflating: dataset_nlg_v1/data/15021039491160053597.csv
#   inflating: dataset_nlg_v1/data/3695029909534962151.csv
#   inflating: dataset_nlg_v1/data/223685202393173.csv
#   inflating: dataset_nlg_v1/data/5763232756918392671.csv
#   inflating: dataset_nlg_v1/data/6854506131799354054.csv
#   inflating: dataset_nlg_v1/data/6543200772868126805.csv
#   inflating: dataset_nlg_v1/data/223685202393759.csv
#   inflating: dataset_nlg_v1/data/419706565039220128.csv
#   inflating: dataset_nlg_v1/data/16237086259223699682.csv
#   inflating: dataset_nlg_v1/data/17854171576454346105.csv
#   inflating: dataset_nlg_v1/data/16881177035147787151.csv
#   inflating: dataset_nlg_v1/data/5896569846392112423.csv
#   inflating: dataset_nlg_v1/data/14344962032033590865.csv
#   inflating: dataset_nlg_v1/data/13748814504776533712.csv
#   inflating: dataset_nlg_v1/data/7284453891909149131.csv
#   inflating: dataset_nlg_v1/data/17204067107875885332.csv
#   inflating: dataset_nlg_v1/data/6952079327611684559.csv
#   inflating: dataset_nlg_v1/data/223685202387553.csv
#   inflating: dataset_nlg_v1/data/223685202393798.csv
#   inflating: dataset_nlg_v1/data/5113283041315558979.csv
#   inflating: dataset_nlg_v1/data/15724564169584655758.csv
#   inflating: dataset_nlg_v1/data/15420523876454400020.csv
#   inflating: dataset_nlg_v1/data/10419996416110220056.csv
#   inflating: dataset_nlg_v1/data/12101023910825945577.csv
#   inflating: dataset_nlg_v1/data/11542637980131069133.csv
#   inflating: dataset_nlg_v1/data/15668341550530763607.csv
#   inflating: dataset_nlg_v1/data/3800559834676326903.csv
#   inflating: dataset_nlg_v1/data/11858865124694628874.csv
#   inflating: dataset_nlg_v1/data/223685202389329.csv
#   inflating: dataset_nlg_v1/data/1580876976408290213.csv
#   inflating: dataset_nlg_v1/data/8025514248252049040.csv
#   inflating: dataset_nlg_v1/data/3226796936197974594.csv
#   inflating: dataset_nlg_v1/data/223685202389211.csv
#   inflating: dataset_nlg_v1/data/223685202385951.csv
#   inflating: dataset_nlg_v1/data/17964390333389051516.csv
#   inflating: dataset_nlg_v1/data/223685202393563.csv
#   inflating: dataset_nlg_v1/data/9815724521276861212.csv
#   inflating: dataset_nlg_v1/data/7864565361077413659.csv
#   inflating: dataset_nlg_v1/data/9630127223287795253.csv
#   inflating: dataset_nlg_v1/data/1986249624709637147.csv
#   inflating: dataset_nlg_v1/data/4830708507030829769.csv
#   inflating: dataset_nlg_v1/data/223685202389568.csv
#   inflating: dataset_nlg_v1/data/4226077875157687880.csv
#   inflating: dataset_nlg_v1/data/3786001146172805943.csv
#   inflating: dataset_nlg_v1/data/223685202386263.csv
#   inflating: dataset_nlg_v1/data/812371993475203195.csv
#   inflating: dataset_nlg_v1/data/5757377121527622991.csv
#   inflating: dataset_nlg_v1/data/13552406194201783586.csv
#   inflating: dataset_nlg_v1/data/6807981104375132167.csv
#   inflating: dataset_nlg_v1/data/1988635689417644947.csv
#   inflating: dataset_nlg_v1/data/13486979338845752283.csv
#   inflating: dataset_nlg_v1/data/6156011940135039549.csv
#   inflating: dataset_nlg_v1/data/17705576984815058952.csv
#   inflating: dataset_nlg_v1/data/10365141712143899382.csv
#   inflating: dataset_nlg_v1/data/223685202386140.csv
#   inflating: dataset_nlg_v1/data/1068353892895041932.csv
#   inflating: dataset_nlg_v1/data/223685202392922.csv
#  extracting: dataset_nlg_v1/data/6911355161877947248.csv
#   inflating: dataset_nlg_v1/data/6141900805131040244.csv
#   inflating: dataset_nlg_v1/data/12479980234066614617.csv
#   inflating: dataset_nlg_v1/data/10936361843332984915.csv
#   inflating: dataset_nlg_v1/data/12293042658960870329.csv
#   inflating: dataset_nlg_v1/data/16543647466597667265.csv
#   inflating: dataset_nlg_v1/data/7693037451011496254.csv
#   inflating: dataset_nlg_v1/data/10825029340522083604.csv
#   inflating: dataset_nlg_v1/data/4244508840352653000.csv
#   inflating: dataset_nlg_v1/data/2895069042815063727.csv
#  extracting: dataset_nlg_v1/data/1474525584973735013.csv
#   inflating: dataset_nlg_v1/data/10618203217191458750.csv
#   inflating: dataset_nlg_v1/data/785162729106121054.csv
#   inflating: dataset_nlg_v1/data/223685202387923.csv
#   inflating: dataset_nlg_v1/data/17243532867663905614.csv
#  extracting: dataset_nlg_v1/data/223685202392949.csv
#   inflating: dataset_nlg_v1/data/10909104111278685093.csv
#   inflating: dataset_nlg_v1/data/5398152317125211077.csv
#   inflating: dataset_nlg_v1/data/477870168537935210.csv
#   inflating: dataset_nlg_v1/data/17823040744726042238.csv
#   inflating: dataset_nlg_v1/data/223685202394487.csv
#   inflating: dataset_nlg_v1/data/12478978492001020337.csv
#   inflating: dataset_nlg_v1/data/4096345665098414489.csv
#   inflating: dataset_nlg_v1/data/3637110060913091073.csv
#   inflating: dataset_nlg_v1/data/226939037022974742.csv
#   inflating: dataset_nlg_v1/data/1247456015152865322.csv
#   inflating: dataset_nlg_v1/data/223685202396024.csv
#   inflating: dataset_nlg_v1/data/463613931291345858.csv
#   inflating: dataset_nlg_v1/data/1726084916011360403.csv
#   inflating: dataset_nlg_v1/data/223685202393131.csv
#   inflating: dataset_nlg_v1/data/223685202388596.csv
#   inflating: dataset_nlg_v1/data/17160753179545797121.csv
#   inflating: dataset_nlg_v1/data/6486233373414875889.csv
#   inflating: dataset_nlg_v1/data/1486524763340158543.csv
#   inflating: dataset_nlg_v1/data/2074966394268070866.csv
#   inflating: dataset_nlg_v1/data/7553458679691756795.csv
#   inflating: dataset_nlg_v1/data/8920862001067069994.csv
#   inflating: dataset_nlg_v1/data/8119916911025123349.csv
#   inflating: dataset_nlg_v1/data/223685202393932.csv
#   inflating: dataset_nlg_v1/data/223685202389217.csv
#   inflating: dataset_nlg_v1/data/7568621913189334067.csv
#   inflating: dataset_nlg_v1/data/1661198304725385188.csv
#   inflating: dataset_nlg_v1/data/13764749467286870915.csv
#   inflating: dataset_nlg_v1/data/3863559748520900989.csv
#   inflating: dataset_nlg_v1/data/15886357718737287336.csv
#   inflating: dataset_nlg_v1/data/15074700782550774698.csv
#   inflating: dataset_nlg_v1/data/11370097105706140193.csv
#   inflating: dataset_nlg_v1/data/223685202387568.csv
#   inflating: dataset_nlg_v1/data/223685202391434.csv
#   inflating: dataset_nlg_v1/data/5647060889794556531.csv
#   inflating: dataset_nlg_v1/data/4365616455838291587.csv
#   inflating: dataset_nlg_v1/data/10475937055631100089.csv
#   inflating: dataset_nlg_v1/data/6978517102930291059.csv
#   inflating: dataset_nlg_v1/data/223685202387051.csv
#   inflating: dataset_nlg_v1/data/4485841809542685856.csv
#   inflating: dataset_nlg_v1/data/16499295691170727711.csv
#   inflating: dataset_nlg_v1/data/12123095065173925126.csv
#   inflating: dataset_nlg_v1/data/223685202391488.csv
#   inflating: dataset_nlg_v1/data/223685202391183.csv
#   inflating: dataset_nlg_v1/data/223685202388241.csv
#   inflating: dataset_nlg_v1/data/12566130766742860765.csv
#   inflating: dataset_nlg_v1/data/12562366953339011116.csv
#   inflating: dataset_nlg_v1/data/5019071115012134052.csv
#   inflating: dataset_nlg_v1/data/11738746259704837422.csv
#   inflating: dataset_nlg_v1/data/223685202391053.csv
#   inflating: dataset_nlg_v1/data/8261102257656041901.csv
#   inflating: dataset_nlg_v1/data/2167264649590821988.csv
#   inflating: dataset_nlg_v1/data/223685202395552.csv
#   inflating: dataset_nlg_v1/data/223685202390301.csv
#   inflating: dataset_nlg_v1/data/223685202389250.csv
#   inflating: dataset_nlg_v1/data/2511838056598717113.csv
#   inflating: dataset_nlg_v1/data/223685202386511.csv
#   inflating: dataset_nlg_v1/data/5775445777776915648.csv
#   inflating: dataset_nlg_v1/data/9289451021653684524.csv
#   inflating: dataset_nlg_v1/data/8384424795019922051.csv
#   inflating: dataset_nlg_v1/data/9677366792698254358.csv
#   inflating: dataset_nlg_v1/data/17235716046726637755.csv
#   inflating: dataset_nlg_v1/data/223685202385883.csv
#   inflating: dataset_nlg_v1/data/17600597237282002951.csv
#   inflating: dataset_nlg_v1/data/6458102102430053797.csv
#   inflating: dataset_nlg_v1/data/5425782020110827606.csv
#   inflating: dataset_nlg_v1/data/456780761301530860.csv
#   inflating: dataset_nlg_v1/data/16056269065776878914.csv
#   inflating: dataset_nlg_v1/data/223685202392375.csv
#   inflating: dataset_nlg_v1/data/223685202388764.csv
#   inflating: dataset_nlg_v1/data/3679204289554942840.csv
#   inflating: dataset_nlg_v1/data/223685202391292.csv
#   inflating: dataset_nlg_v1/data/16471820490305613599.csv
#   inflating: dataset_nlg_v1/data/13665472660901828478.csv
#   inflating: dataset_nlg_v1/data/12353170808401646896.csv
#   inflating: dataset_nlg_v1/data/10221574935590277064.csv
#   inflating: dataset_nlg_v1/data/6492049553755189770.csv
#   inflating: dataset_nlg_v1/data/14385219526468661999.csv
#   inflating: dataset_nlg_v1/data/4010952203814670008.csv
#   inflating: dataset_nlg_v1/data/17166592409749507378.csv
#   inflating: dataset_nlg_v1/data/223685202388718.csv
#   inflating: dataset_nlg_v1/data/2044798495443759320.csv
#   inflating: dataset_nlg_v1/data/15650880996069276198.csv
#   inflating: dataset_nlg_v1/data/17779060823069192356.csv
#   inflating: dataset_nlg_v1/data/8529298552801971366.csv
#   inflating: dataset_nlg_v1/data/223685202388095.csv
#   inflating: dataset_nlg_v1/data/223685202387503.csv
#   inflating: dataset_nlg_v1/data/223685202386467.csv
#   inflating: dataset_nlg_v1/data/11128909314334029362.csv
#   inflating: dataset_nlg_v1/data/223685202392766.csv
#   inflating: dataset_nlg_v1/data/223685202393392.csv
#   inflating: dataset_nlg_v1/data/88342927548643289.csv
#   inflating: dataset_nlg_v1/data/3827217960518000660.csv
#   inflating: dataset_nlg_v1/data/8316035465116973437.csv
#   inflating: dataset_nlg_v1/data/223685202395723.csv
#   inflating: dataset_nlg_v1/data/14116646049552865498.csv
#   inflating: dataset_nlg_v1/data/15744943663545495799.csv
#   inflating: dataset_nlg_v1/data/8820081643440121438.csv
#   inflating: dataset_nlg_v1/data/223685202389299.csv
#   inflating: dataset_nlg_v1/data/6084571635509542561.csv
#   inflating: dataset_nlg_v1/data/3655688392268784625.csv
#   inflating: dataset_nlg_v1/data/9180306802599882088.csv
#   inflating: dataset_nlg_v1/data/223685202385867.csv
#   inflating: dataset_nlg_v1/data/642722931292848207.csv
#   inflating: dataset_nlg_v1/data/13606258095118290318.csv
#   inflating: dataset_nlg_v1/data/6479717382229846035.csv
#   inflating: dataset_nlg_v1/data/1507289570663827005.csv
#   inflating: dataset_nlg_v1/data/223685202393671.csv
#   inflating: dataset_nlg_v1/data/9480744391036514809.csv
#   inflating: dataset_nlg_v1/data/17032867900584031331.csv
#   inflating: dataset_nlg_v1/data/3787594781804527195.csv
#   inflating: dataset_nlg_v1/data/18208251938361371165.csv
#   inflating: dataset_nlg_v1/data/961082379725145721.csv
#   inflating: dataset_nlg_v1/data/4171822502707712173.csv
#   inflating: dataset_nlg_v1/data/11626680365403419017.csv
#   inflating: dataset_nlg_v1/data/1722396171695293249.csv
#   inflating: dataset_nlg_v1/data/16530189859978202484.csv
#   inflating: dataset_nlg_v1/data/1440172005313833312.csv
#   inflating: dataset_nlg_v1/data/13355607582753995384.csv
#   inflating: dataset_nlg_v1/data/16166902767956798324.csv
#   inflating: dataset_nlg_v1/data/9680285070242973230.csv
#   inflating: dataset_nlg_v1/data/223685202386468.csv
#   inflating: dataset_nlg_v1/data/223685202387697.csv
#   inflating: dataset_nlg_v1/data/223685202392777.csv
#   inflating: dataset_nlg_v1/data/16476104953497991845.csv
#   inflating: dataset_nlg_v1/data/223685202387907.csv
#   inflating: dataset_nlg_v1/data/7076821899184500126.csv
#   inflating: dataset_nlg_v1/data/11070474296995175024.csv
#   inflating: dataset_nlg_v1/data/223685202388255.csv
#   inflating: dataset_nlg_v1/data/9948175000481150280.csv
#   inflating: dataset_nlg_v1/data/223685202391975.csv
#   inflating: dataset_nlg_v1/data/223685202387260.csv
#   inflating: dataset_nlg_v1/data/6705480469621651271.csv
#   inflating: dataset_nlg_v1/data/18267459429837122480.csv
#   inflating: dataset_nlg_v1/data/223685202396148.csv
#   inflating: dataset_nlg_v1/data/223685202392371.csv
#   inflating: dataset_nlg_v1/data/17332087030601646647.csv
#   inflating: dataset_nlg_v1/data/10312226176634614833.csv
#   inflating: dataset_nlg_v1/data/8359412072100563413.csv
#   inflating: dataset_nlg_v1/data/13905855144542842759.csv
#   inflating: dataset_nlg_v1/data/2826481860494019844.csv
#   inflating: dataset_nlg_v1/data/708523359805071789.csv
#   inflating: dataset_nlg_v1/data/223685202389360.csv
#   inflating: dataset_nlg_v1/data/955732098256412821.csv
#   inflating: dataset_nlg_v1/data/5681866482204127057.csv
#   inflating: dataset_nlg_v1/data/16428959120993292964.csv
#   inflating: dataset_nlg_v1/data/13916013797168851502.csv
#   inflating: dataset_nlg_v1/data/5386027133656372846.csv
#   inflating: dataset_nlg_v1/data/17446344884596825800.csv
#   inflating: dataset_nlg_v1/data/8851089726951256661.csv
#   inflating: dataset_nlg_v1/data/223685202389288.csv
#   inflating: dataset_nlg_v1/data/223685202392980.csv
#   inflating: dataset_nlg_v1/data/7196206996034200934.csv
#   inflating: dataset_nlg_v1/data/9333146381328034716.csv
#   inflating: dataset_nlg_v1/data/8685757632728680248.csv
#   inflating: dataset_nlg_v1/data/3888902465291074892.csv
#   inflating: dataset_nlg_v1/data/11413640089436721249.csv
#   inflating: dataset_nlg_v1/data/16512972372585107396.csv
#   inflating: dataset_nlg_v1/data/11799926620330233666.csv
#   inflating: dataset_nlg_v1/data/6192118491301283092.csv
#   inflating: dataset_nlg_v1/data/8659962581048467704.csv
#   inflating: dataset_nlg_v1/data/5497704708350047738.csv
#   inflating: dataset_nlg_v1/data/223685202395108.csv
#   inflating: dataset_nlg_v1/data/223685202387715.csv
#   inflating: dataset_nlg_v1/data/223685202387284.csv
#   inflating: dataset_nlg_v1/data/4865145316831467313.csv
#   inflating: dataset_nlg_v1/data/53387684109898177.csv
#   inflating: dataset_nlg_v1/data/4020109049004295284.csv
#   inflating: dataset_nlg_v1/data/223685202395649.csv
#   inflating: dataset_nlg_v1/data/1542189890518526339.csv
#   inflating: dataset_nlg_v1/data/223685202392045.csv
#   inflating: dataset_nlg_v1/data/4514682187792095625.csv
#   inflating: dataset_nlg_v1/data/1095247352947306190.csv
#   inflating: dataset_nlg_v1/data/7677692127220688766.csv
#   inflating: dataset_nlg_v1/data/9649770256985962965.csv
#   inflating: dataset_nlg_v1/data/223685202388901.csv
#   inflating: dataset_nlg_v1/data/223685202393534.csv
#   inflating: dataset_nlg_v1/data/223685202395402.csv
#   inflating: dataset_nlg_v1/data/10926685569869139635.csv
#   inflating: dataset_nlg_v1/data/12293858086476728598.csv
#   inflating: dataset_nlg_v1/data/7567313414860031883.csv
#   inflating: dataset_nlg_v1/data/12579494931547269490.csv
#   inflating: dataset_nlg_v1/data/223685202395429.csv
#   inflating: dataset_nlg_v1/data/223685202392090.csv
#   inflating: dataset_nlg_v1/data/13070504101521447168.csv
#   inflating: dataset_nlg_v1/data/17324378202268191434.csv
#   inflating: dataset_nlg_v1/data/18254344756228692482.csv
#   inflating: dataset_nlg_v1/data/223685202392948.csv
#   inflating: dataset_nlg_v1/data/964369256434047227.csv
#   inflating: dataset_nlg_v1/data/16513217550324350670.csv
#   inflating: dataset_nlg_v1/data/223685202392431.csv
#   inflating: dataset_nlg_v1/data/12079664095026996745.csv
#   inflating: dataset_nlg_v1/data/16667001103737124358.csv
#   inflating: dataset_nlg_v1/data/227546211608414520.csv
#   inflating: dataset_nlg_v1/data/9431790149150324536.csv
#   inflating: dataset_nlg_v1/data/3209255012041014109.csv
#   inflating: dataset_nlg_v1/data/7736572629635935571.csv
#   inflating: dataset_nlg_v1/data/6201773246435293827.csv
#   inflating: dataset_nlg_v1/data/10752126732336441445.csv
#   inflating: dataset_nlg_v1/data/223685202394918.csv
#   inflating: dataset_nlg_v1/data/12863680955295456967.csv
#   inflating: dataset_nlg_v1/data/223685202392399.csv
#   inflating: dataset_nlg_v1/data/8471839498731358084.csv
#   inflating: dataset_nlg_v1/data/16503025862990079817.csv
#   inflating: dataset_nlg_v1/data/9314955840356245206.csv
#   inflating: dataset_nlg_v1/data/223685202391629.csv
#   inflating: dataset_nlg_v1/data/223685202395885.csv
#   inflating: dataset_nlg_v1/data/17371412760543305516.csv
#   inflating: dataset_nlg_v1/data/10717045154938246254.csv
#   inflating: dataset_nlg_v1/data/223685202389556.csv
#   inflating: dataset_nlg_v1/data/16708175255495462564.csv
#   inflating: dataset_nlg_v1/data/11594192479018294248.csv
#   inflating: dataset_nlg_v1/data/4176828105235930323.csv
#   inflating: dataset_nlg_v1/data/14112782235670848080.csv
#   inflating: dataset_nlg_v1/data/5905357580938124026.csv
#   inflating: dataset_nlg_v1/data/17807664138686524221.csv
#   inflating: dataset_nlg_v1/data/2309949220181839475.csv
#   inflating: dataset_nlg_v1/data/11613995716048667228.csv
#   inflating: dataset_nlg_v1/data/14017255493166770388.csv
#   inflating: dataset_nlg_v1/data/223685202387058.csv
#   inflating: dataset_nlg_v1/data/16897233613825545740.csv
#   inflating: dataset_nlg_v1/data/17734402472439083864.csv
#   inflating: dataset_nlg_v1/data/223685202395506.csv
#   inflating: dataset_nlg_v1/data/15749351986863647952.csv
#   inflating: dataset_nlg_v1/data/3112107463695442856.csv
#   inflating: dataset_nlg_v1/data/10369197334361055023.csv
#   inflating: dataset_nlg_v1/data/3684135868542031919.csv
#   inflating: dataset_nlg_v1/data/3935014684521196.csv
#   inflating: dataset_nlg_v1/data/10782584659453487747.csv
#   inflating: dataset_nlg_v1/data/13303686524372394400.csv
#   inflating: dataset_nlg_v1/data/14539430836154117229.csv
#   inflating: dataset_nlg_v1/data/3240980274668423542.csv
#  extracting: dataset_nlg_v1/data/223685202392775.csv
#   inflating: dataset_nlg_v1/data/10357047876680649822.csv
#   inflating: dataset_nlg_v1/data/4946140242203583772.csv
#   inflating: dataset_nlg_v1/data/223685202391258.csv
#   inflating: dataset_nlg_v1/data/223685202393623.csv
#   inflating: dataset_nlg_v1/data/7180757354866156348.csv
#   inflating: dataset_nlg_v1/data/8837988949712129201.csv
#   inflating: dataset_nlg_v1/data/223685202387291.csv
#   inflating: dataset_nlg_v1/data/6665773243238676331.csv
#   inflating: dataset_nlg_v1/data/14499506681574421469.csv
#   inflating: dataset_nlg_v1/data/223685202395370.csv
#   inflating: dataset_nlg_v1/data/6448396938883180798.csv
#   inflating: dataset_nlg_v1/data/1105215759093966521.csv
#   inflating: dataset_nlg_v1/data/11814338640939462958.csv
#   inflating: dataset_nlg_v1/data/18338430324951008787.csv
#   inflating: dataset_nlg_v1/data/13648922839250375011.csv
#   inflating: dataset_nlg_v1/data/3814236492958600472.csv
#   inflating: dataset_nlg_v1/data/14093897982971390279.csv
#   inflating: dataset_nlg_v1/data/6012739444921820821.csv
#   inflating: dataset_nlg_v1/data/223685202388577.csv
#   inflating: dataset_nlg_v1/data/11820542027507002143.csv
#   inflating: dataset_nlg_v1/data/223685202395361.csv
#   inflating: dataset_nlg_v1/data/6044099014175969911.csv
#   inflating: dataset_nlg_v1/data/11413023427550541233.csv
#   inflating: dataset_nlg_v1/data/5218661761863285048.csv
#   inflating: dataset_nlg_v1/data/6336696639848258203.csv
#   inflating: dataset_nlg_v1/data/223685202394940.csv
#   inflating: dataset_nlg_v1/data/18184697077614273129.csv
#   inflating: dataset_nlg_v1/data/15024502212662293853.csv
#   inflating: dataset_nlg_v1/data/18417432861956786494.csv
#   inflating: dataset_nlg_v1/data/8077433866727016702.csv
#   inflating: dataset_nlg_v1/data/223685202394376.csv
#   inflating: dataset_nlg_v1/data/10216767403651508760.csv
#   inflating: dataset_nlg_v1/data/15361950312575488305.csv
#   inflating: dataset_nlg_v1/data/223685202389737.csv
#   inflating: dataset_nlg_v1/data/257499046060218949.csv
#   inflating: dataset_nlg_v1/data/824172639126424166.csv
#   inflating: dataset_nlg_v1/data/15712149662986773079.csv
#   inflating: dataset_nlg_v1/data/223685202396179.csv
#   inflating: dataset_nlg_v1/data/16494472591421432362.csv
#   inflating: dataset_nlg_v1/data/10546289767567691375.csv
#   inflating: dataset_nlg_v1/data/13280596727567004200.csv
#   inflating: dataset_nlg_v1/data/223685202392941.csv
#   inflating: dataset_nlg_v1/data/17203874510783666015.csv
#   inflating: dataset_nlg_v1/data/1179029311589120950.csv
#   inflating: dataset_nlg_v1/data/16463011685778918541.csv
#   inflating: dataset_nlg_v1/data/10696635854492749146.csv
#   inflating: dataset_nlg_v1/data/16838354407797064495.csv
#   inflating: dataset_nlg_v1/data/15891378040599772073.csv
#   inflating: dataset_nlg_v1/data/10874621489299647578.csv
#   inflating: dataset_nlg_v1/data/12802595018091784373.csv
#   inflating: dataset_nlg_v1/data/223685202389921.csv
#   inflating: dataset_nlg_v1/data/223685202391788.csv
#   inflating: dataset_nlg_v1/data/16382627985803994076.csv
#   inflating: dataset_nlg_v1/data/11841862133813904955.csv
#   inflating: dataset_nlg_v1/data/13710655662760829968.csv
#   inflating: dataset_nlg_v1/data/10075382300672436898.csv
#   inflating: dataset_nlg_v1/data/12578370332787718473.csv
#   inflating: dataset_nlg_v1/data/1963141845104399620.csv
#   inflating: dataset_nlg_v1/data/3119053059150840926.csv
#   inflating: dataset_nlg_v1/data/223685202387708.csv
#   inflating: dataset_nlg_v1/data/6586138909597026664.csv
#   inflating: dataset_nlg_v1/data/223685202394964.csv
#   inflating: dataset_nlg_v1/data/223685202393034.csv
#   inflating: dataset_nlg_v1/data/84604811504411028.csv
#   inflating: dataset_nlg_v1/data/12144124726161176493.csv
#   inflating: dataset_nlg_v1/data/11563792857583712760.csv
#   inflating: dataset_nlg_v1/data/223685202388149.csv
#   inflating: dataset_nlg_v1/data/6735981379338254237.csv
#   inflating: dataset_nlg_v1/data/8282884451285509125.csv
#   inflating: dataset_nlg_v1/data/223685202396057.csv
#   inflating: dataset_nlg_v1/data/5818648984923472164.csv
#   inflating: dataset_nlg_v1/data/2040167061848384095.csv
#   inflating: dataset_nlg_v1/data/8830660960121802689.csv
#   inflating: dataset_nlg_v1/data/9341912251777789109.csv
#   inflating: dataset_nlg_v1/data/10465672761083406507.csv
#   inflating: dataset_nlg_v1/data/1445691768795727887.csv
#   inflating: dataset_nlg_v1/data/223685202386702.csv
#   inflating: dataset_nlg_v1/data/9981127764542585648.csv
#   inflating: dataset_nlg_v1/data/2449670779178963263.csv
#   inflating: dataset_nlg_v1/data/7431286240307403881.csv
#   inflating: dataset_nlg_v1/data/223685202389599.csv
#   inflating: dataset_nlg_v1/data/12620771983855498039.csv
#   inflating: dataset_nlg_v1/data/223685202387946.csv
#   inflating: dataset_nlg_v1/data/13018432503877774072.csv
#   inflating: dataset_nlg_v1/data/223685202390086.csv
#   inflating: dataset_nlg_v1/data/9540050830575750459.csv
#   inflating: dataset_nlg_v1/data/9860730663723323081.csv
#   inflating: dataset_nlg_v1/data/223685202393892.csv
#   inflating: dataset_nlg_v1/data/3418452029396943540.csv
#   inflating: dataset_nlg_v1/data/16289136492923584842.csv
#   inflating: dataset_nlg_v1/data/223685202392826.csv
#   inflating: dataset_nlg_v1/data/1439913772827038019.csv
#   inflating: dataset_nlg_v1/data/6698576752786735526.csv
#   inflating: dataset_nlg_v1/data/1138212398053004226.csv
#   inflating: dataset_nlg_v1/data/223685202391634.csv
#   inflating: dataset_nlg_v1/data/12570376525613734105.csv
#   inflating: dataset_nlg_v1/data/5555638320951652211.csv
#   inflating: dataset_nlg_v1/data/223685202391925.csv
#   inflating: dataset_nlg_v1/data/295037066730263162.csv
#   inflating: dataset_nlg_v1/data/7404691757647565751.csv
#   inflating: dataset_nlg_v1/data/11543277916039717173.csv
#   inflating: dataset_nlg_v1/data/16946390174268870212.csv
#   inflating: dataset_nlg_v1/data/11595679288646056825.csv
#   inflating: dataset_nlg_v1/data/223685202389994.csv
#   inflating: dataset_nlg_v1/data/223685202389385.csv
#   inflating: dataset_nlg_v1/data/14890263740157296772.csv
#   inflating: dataset_nlg_v1/data/12558230834840430098.csv
#   inflating: dataset_nlg_v1/data/16219233668401374619.csv
#   inflating: dataset_nlg_v1/data/12437658555260394296.csv
#   inflating: dataset_nlg_v1/data/223685202395377.csv
#   inflating: dataset_nlg_v1/data/12067341218349517992.csv
#   inflating: dataset_nlg_v1/data/10981924410069716043.csv
#   inflating: dataset_nlg_v1/data/13066601026897680392.csv
#   inflating: dataset_nlg_v1/data/2277876768668953675.csv
#   inflating: dataset_nlg_v1/data/15225625546772161340.csv
#   inflating: dataset_nlg_v1/data/223685202388719.csv
#   inflating: dataset_nlg_v1/data/223685202393883.csv
#   inflating: dataset_nlg_v1/data/15191186937564362646.csv
#   inflating: dataset_nlg_v1/data/4143785846017176317.csv
#   inflating: dataset_nlg_v1/data/4746120041796402535.csv
#   inflating: dataset_nlg_v1/data/9571376582083318405.csv
#   inflating: dataset_nlg_v1/data/1800958919622801420.csv
#   inflating: dataset_nlg_v1/data/12788047820546584274.csv
#   inflating: dataset_nlg_v1/data/6055074067146674990.csv
#   inflating: dataset_nlg_v1/data/223685202390309.csv
#   inflating: dataset_nlg_v1/data/8626854887343697645.csv
#   inflating: dataset_nlg_v1/data/223685202388867.csv
#   inflating: dataset_nlg_v1/data/14488123849474706842.csv
#   inflating: dataset_nlg_v1/data/223685202387046.csv
#   inflating: dataset_nlg_v1/data/15515683125584652409.csv
#   inflating: dataset_nlg_v1/data/18433455131565525953.csv
#   inflating: dataset_nlg_v1/data/608640829335979334.csv
#   inflating: dataset_nlg_v1/data/4482504398408685791.csv
#   inflating: dataset_nlg_v1/data/17740947872843840930.csv
#   inflating: dataset_nlg_v1/data/6052932874602836594.csv
#   inflating: dataset_nlg_v1/data/2030694153116049039.csv
#   inflating: dataset_nlg_v1/data/16684238966670646258.csv
#   inflating: dataset_nlg_v1/data/223685202386700.csv
#   inflating: dataset_nlg_v1/data/5391683634134083406.csv
#   inflating: dataset_nlg_v1/data/223685202395298.csv
#   inflating: dataset_nlg_v1/data/223685202386705.csv
#   inflating: dataset_nlg_v1/data/14846625309324684952.csv
#   inflating: dataset_nlg_v1/data/13948049172689163375.csv
#   inflating: dataset_nlg_v1/data/8513103750454901110.csv
#   inflating: dataset_nlg_v1/data/13920070153559799510.csv
#   inflating: dataset_nlg_v1/data/814669831862122620.csv
#   inflating: dataset_nlg_v1/data/223685202392890.csv
#   inflating: dataset_nlg_v1/data/13934718667769285258.csv
#   inflating: dataset_nlg_v1/data/223685202393634.csv
#   inflating: dataset_nlg_v1/data/3990623717519741577.csv
#   inflating: dataset_nlg_v1/data/223685202390202.csv
#   inflating: dataset_nlg_v1/data/6662994721128710842.csv
#   inflating: dataset_nlg_v1/data/223685202386196.csv
#   inflating: dataset_nlg_v1/data/4679684735475720070.csv
#   inflating: dataset_nlg_v1/data/15913920503371781051.csv
#   inflating: dataset_nlg_v1/data/13254291902695880402.csv
#   inflating: dataset_nlg_v1/data/16919553061992940047.csv
#   inflating: dataset_nlg_v1/data/3934471223983924366.csv
#   inflating: dataset_nlg_v1/data/9440981524262276995.csv
#   inflating: dataset_nlg_v1/data/3737851036017923919.csv
#   inflating: dataset_nlg_v1/data/223685202392667.csv
#   inflating: dataset_nlg_v1/data/223685202395777.csv
#   inflating: dataset_nlg_v1/data/1385752985004834482.csv
#   inflating: dataset_nlg_v1/data/12579169653467922541.csv
#   inflating: dataset_nlg_v1/data/2020325036691948056.csv
#   inflating: dataset_nlg_v1/data/14632991426601735092.csv
#   inflating: dataset_nlg_v1/data/13357736233008028587.csv
#   inflating: dataset_nlg_v1/data/10173982496751335496.csv
#   inflating: dataset_nlg_v1/data/14225435186982038869.csv
#   inflating: dataset_nlg_v1/data/14049377170471067390.csv
#   inflating: dataset_nlg_v1/data/223685202388133.csv
#   inflating: dataset_nlg_v1/data/223685202396407.csv
#   inflating: dataset_nlg_v1/data/3311721874525368337.csv
#   inflating: dataset_nlg_v1/data/11917968576303607688.csv
#   inflating: dataset_nlg_v1/data/1923475967167578390.csv
#   inflating: dataset_nlg_v1/data/7686648081205578328.csv
#   inflating: dataset_nlg_v1/data/12286260800872971608.csv
#   inflating: dataset_nlg_v1/data/14845213812015143098.csv
#   inflating: dataset_nlg_v1/data/223685202387110.csv
#   inflating: dataset_nlg_v1/data/17562556702333737019.csv
#   inflating: dataset_nlg_v1/data/1988093324977283105.csv
#   inflating: dataset_nlg_v1/data/1732739639898671292.csv
#   inflating: dataset_nlg_v1/data/3677622830139801544.csv
#   inflating: dataset_nlg_v1/data/9299195573959253948.csv
#   inflating: dataset_nlg_v1/data/5323948521342695033.csv
#   inflating: dataset_nlg_v1/data/223685202394474.csv
#   inflating: dataset_nlg_v1/data/4673238434675689047.csv
#   inflating: dataset_nlg_v1/data/223685202393822.csv
#   inflating: dataset_nlg_v1/data/2344260115503267767.csv
#   inflating: dataset_nlg_v1/data/223685202393954.csv
#   inflating: dataset_nlg_v1/data/16771908538337388361.csv
#   inflating: dataset_nlg_v1/data/223685202388185.csv
#   inflating: dataset_nlg_v1/data/8097979483171588891.csv
#   inflating: dataset_nlg_v1/data/16175855057225689620.csv
#   inflating: dataset_nlg_v1/data/12296785161921746294.csv
#   inflating: dataset_nlg_v1/data/3495685420195926236.csv
#   inflating: dataset_nlg_v1/data/3787079826331363903.csv
#   inflating: dataset_nlg_v1/data/11084657019082330631.csv
#   inflating: dataset_nlg_v1/data/16859833408753664325.csv
#   inflating: dataset_nlg_v1/data/4619804946839154525.csv
#   inflating: dataset_nlg_v1/data/1601799917689066977.csv
#   inflating: dataset_nlg_v1/data/223685202386601.csv
#   inflating: dataset_nlg_v1/data/2722210393581420039.csv
#   inflating: dataset_nlg_v1/data/8076428185049030266.csv
#   inflating: dataset_nlg_v1/data/223685202388230.csv
#   inflating: dataset_nlg_v1/data/14586349066647107074.csv
#   inflating: dataset_nlg_v1/data/5991395498903099025.csv
#   inflating: dataset_nlg_v1/data/2879182500832829756.csv
#   inflating: dataset_nlg_v1/data/3975707620182701332.csv
#   inflating: dataset_nlg_v1/data/16846295473106432981.csv
#   inflating: dataset_nlg_v1/data/7819414640479347662.csv
#   inflating: dataset_nlg_v1/data/15930309117400711286.csv
#   inflating: dataset_nlg_v1/data/6831950247448202785.csv
#   inflating: dataset_nlg_v1/data/14583470020688495322.csv
#   inflating: dataset_nlg_v1/data/293695690997514168.csv
#   inflating: dataset_nlg_v1/data/223685202388210.csv
#   inflating: dataset_nlg_v1/data/1977157839230122314.csv
#   inflating: dataset_nlg_v1/data/11311159822661953499.csv
#   inflating: dataset_nlg_v1/data/11540111074239687304.csv
#   inflating: dataset_nlg_v1/data/5720442385118542432.csv
#   inflating: dataset_nlg_v1/data/3098845923150466155.csv
#   inflating: dataset_nlg_v1/data/223685202390125.csv
#   inflating: dataset_nlg_v1/data/223685202390063.csv
#   inflating: dataset_nlg_v1/data/12374080688500811081.csv
#   inflating: dataset_nlg_v1/data/8441039893983771079.csv
#   inflating: dataset_nlg_v1/data/15165572308878673921.csv
#   inflating: dataset_nlg_v1/data/12842669566571531508.csv
#   inflating: dataset_nlg_v1/data/5824082751224913955.csv
#  extracting: dataset_nlg_v1/data/223685202394761.csv
#   inflating: dataset_nlg_v1/data/223685202386432.csv
#   inflating: dataset_nlg_v1/data/223685202391256.csv
#   inflating: dataset_nlg_v1/data/17081430348761672954.csv
#   inflating: dataset_nlg_v1/data/223685202392495.csv
#   inflating: dataset_nlg_v1/data/14784075272067901231.csv
#   inflating: dataset_nlg_v1/data/18176618671075197938.csv
#   inflating: dataset_nlg_v1/data/223685202394760.csv
#   inflating: dataset_nlg_v1/data/223685202396172.csv
#   inflating: dataset_nlg_v1/data/16870901889842521345.csv
#   inflating: dataset_nlg_v1/data/223685202387371.csv
#   inflating: dataset_nlg_v1/data/223685202396233.csv
#   inflating: dataset_nlg_v1/data/16889078548588701547.csv
#   inflating: dataset_nlg_v1/data/4499169787069166481.csv
#   inflating: dataset_nlg_v1/data/223685202391176.csv
#   inflating: dataset_nlg_v1/data/223685202394125.csv
#   inflating: dataset_nlg_v1/data/223685202391657.csv
#   inflating: dataset_nlg_v1/data/223685202389456.csv
#   inflating: dataset_nlg_v1/data/10868953353095362899.csv
#   inflating: dataset_nlg_v1/data/12550823613288537378.csv
#   inflating: dataset_nlg_v1/data/9175697058955277687.csv
#   inflating: dataset_nlg_v1/data/223685202386799.csv
#   inflating: dataset_nlg_v1/data/10230924909565668590.csv
# ...
#   inflating: dataset_nlg_v1/data/223685202391862.csv
#   inflating: dataset_nlg_v1/data/951790963114278207.csv
#   inflating: dataset_nlg_v1/data/7684399316899001290.csv
#   inflating: dataset_nlg_v1/data/223685202388048.csv
#   inflating: dataset_nlg_v1/data/223685202394642.csv
#   inflating: dataset_nlg_v1/data/3857948018144179400.csv
#   inflating: dataset_nlg_v1/data/9545545582739308924.csv
#   inflating: dataset_nlg_v1/data/593980789543204888.csv
#   inflating: dataset_nlg_v1/data/10157143410505030887.csv
#   inflating: dataset_nlg_v1/data/10564542212586033982.csv
#   inflating: dataset_nlg_v1/data/2351687571501953777.csv
#   inflating: dataset_nlg_v1/data/17637055885620365752.csv
#   inflating: dataset_nlg_v1/data/3621662683250563012.csv
#   inflating: dataset_nlg_v1/data/2728468307580046707.csv
#   inflating: dataset_nlg_v1/data/7984713739470544459.csv
#   inflating: dataset_nlg_v1/data/223685202393399.csv
#   inflating: dataset_nlg_v1/data/2043903702093048987.csv
#   inflating: dataset_nlg_v1/data/15967203530491603142.csv
#   inflating: dataset_nlg_v1/data/223685202388704.csv
#   inflating: dataset_nlg_v1/data/6843331530851969152.csv
#   inflating: dataset_nlg_v1/data/223685202389533.csv
#   inflating: dataset_nlg_v1/data/223685202393004.csv
#   inflating: dataset_nlg_v1/data/9373257084570782695.csv
#   inflating: dataset_nlg_v1/data/3946292765960010664.csv
#   inflating: dataset_nlg_v1/data/2999216675083357435.csv
#   inflating: dataset_nlg_v1/data/223685202389158.csv
#   inflating: dataset_nlg_v1/data/458109406412517855.csv
#   inflating: dataset_nlg_v1/data/8026019173610361582.csv
#   inflating: dataset_nlg_v1/data/6098398887367082873.csv
#   inflating: dataset_nlg_v1/data/223685202392701.csv
#   inflating: dataset_nlg_v1/data/223685202388795.csv
#   inflating: dataset_nlg_v1/data/14176709569601500146.csv
#   inflating: dataset_nlg_v1/data/7735854093070235321.csv
#   inflating: dataset_nlg_v1/data/18286835443147090038.csv
#   inflating: dataset_nlg_v1/data/10122831620179144587.csv
#   inflating: dataset_nlg_v1/data/11382333566374894830.csv
#   inflating: dataset_nlg_v1/data/223685202390454.csv
#   inflating: dataset_nlg_v1/data/6830572488892175624.csv
#   inflating: dataset_nlg_v1/data/593660291424366372.csv
#   inflating: dataset_nlg_v1/data/223685202386592.csv
#   inflating: dataset_nlg_v1/data/11103718374217958713.csv
#   inflating: dataset_nlg_v1/data/9342419017244449807.csv
#   inflating: dataset_nlg_v1/data/223685202395840.csv
#   inflating: dataset_nlg_v1/data/15049791435770915168.csv
#   inflating: dataset_nlg_v1/data/8274711179044436345.csv
#   inflating: dataset_nlg_v1/data/2344021054096515259.csv
#   inflating: dataset_nlg_v1/data/2513165113863253464.csv
#   inflating: dataset_nlg_v1/data/223685202388128.csv
#   inflating: dataset_nlg_v1/data/223685202391153.csv
#   inflating: dataset_nlg_v1/data/7981930216321575233.csv
#   inflating: dataset_nlg_v1/data/2982070411386493116.csv
#   inflating: dataset_nlg_v1/data/1488064463994443240.csv
#   inflating: dataset_nlg_v1/data/223685202392524.csv
#   inflating: dataset_nlg_v1/data/15016129154159700890.csv
#   inflating: dataset_nlg_v1/data/223685202394075.csv
#   inflating: dataset_nlg_v1/data/10458486546351472244.csv
#   inflating: dataset_nlg_v1/data/1339760176279799834.csv
#   inflating: dataset_nlg_v1/data/8545250876561408182.csv
#   inflating: dataset_nlg_v1/data/16941832170812535920.csv
#   inflating: dataset_nlg_v1/data/15622732341849187530.csv
#   inflating: dataset_nlg_v1/data/223685202386418.csv
#   inflating: dataset_nlg_v1/data/223685202392321.csv
#   inflating: dataset_nlg_v1/data/2902082233668721485.csv
#   inflating: dataset_nlg_v1/data/6519582726423338982.csv
#   inflating: dataset_nlg_v1/data/1244545955008950442.csv
#   inflating: dataset_nlg_v1/data/6573882646693394752.csv
#   inflating: dataset_nlg_v1/data/7734060117150679562.csv
#   inflating: dataset_nlg_v1/data/223685202395284.csv
#  extracting: dataset_nlg_v1/data/6841008465740963820.csv
#   inflating: dataset_nlg_v1/data/14980304092696226959.csv
#   inflating: dataset_nlg_v1/data/16063235737666858133.csv
#   inflating: dataset_nlg_v1/data/872508271661507970.csv
#   inflating: dataset_nlg_v1/data/9946541791558944916.csv
#   inflating: dataset_nlg_v1/data/2972143656913477009.csv
#   inflating: dataset_nlg_v1/data/7492011838481274232.csv
#   inflating: dataset_nlg_v1/data/223685202394417.csv
#   inflating: dataset_nlg_v1/data/17696136722446424557.csv
#   inflating: dataset_nlg_v1/data/11936546874387668136.csv
#   inflating: dataset_nlg_v1/data/12920501576813958815.csv
#   inflating: dataset_nlg_v1/data/223685202393012.csv
#   inflating: dataset_nlg_v1/data/223685202391808.csv
#   inflating: dataset_nlg_v1/data/3106806580807667921.csv
#   inflating: dataset_nlg_v1/data/1490026651027385578.csv
#   inflating: dataset_nlg_v1/data/3715470180257373907.csv
#   inflating: dataset_nlg_v1/data/15777753323473558610.csv
#   inflating: dataset_nlg_v1/data/6924069675362196203.csv
#   inflating: dataset_nlg_v1/data/1641545840643312683.csv
#   inflating: dataset_nlg_v1/data/223685202392764.csv
#   inflating: dataset_nlg_v1/data/9494433780670900195.csv
#   inflating: dataset_nlg_v1/data/5595412283423517399.csv
#   inflating: dataset_nlg_v1/data/18353206397362606961.csv
#   inflating: dataset_nlg_v1/data/1349770909644334246.csv
#   inflating: dataset_nlg_v1/data/2262997957138600754.csv
#   inflating: dataset_nlg_v1/data/2755592617822993325.csv
#   inflating: dataset_nlg_v1/data/223685202389249.csv
#   inflating: dataset_nlg_v1/data/10410828367386443483.csv
#   inflating: dataset_nlg_v1/data/2511602006196798493.csv
#   inflating: dataset_nlg_v1/data/11029076831056397362.csv
#   inflating: dataset_nlg_v1/data/223685202394624.csv
#   inflating: dataset_nlg_v1/data/2051492023829132719.csv
#   inflating: dataset_nlg_v1/data/223685202395545.csv
#   inflating: dataset_nlg_v1/data/11930544890796023179.csv
#   inflating: dataset_nlg_v1/data/3992740855606028997.csv
#   inflating: dataset_nlg_v1/data/9746939008606406578.csv
#   inflating: dataset_nlg_v1/data/902367774923113113.csv
#   inflating: dataset_nlg_v1/data/11385329510445320482.csv
#   inflating: dataset_nlg_v1/data/1789706118583772500.csv
#   inflating: dataset_nlg_v1/data/15846541617625951874.csv
#   inflating: dataset_nlg_v1/data/223685202387996.csv
#   inflating: dataset_nlg_v1/data/297974308710216389.csv
#   inflating: dataset_nlg_v1/data/2650151550355718460.csv
#   inflating: dataset_nlg_v1/data/836825234279189989.csv
#   inflating: dataset_nlg_v1/data/223685202386083.csv
#   inflating: dataset_nlg_v1/data/9176855291614102380.csv
#  extracting: dataset_nlg_v1/data/960520772546699316.csv
#   inflating: dataset_nlg_v1/data/7735470691541429271.csv
#   inflating: dataset_nlg_v1/data/223685202393717.csv
#   inflating: dataset_nlg_v1/data/223685202394687.csv
#   inflating: dataset_nlg_v1/data/9106232184071618174.csv
#   inflating: dataset_nlg_v1/data/15506649134368168245.csv
#   inflating: dataset_nlg_v1/data/223685202387999.csv
#   inflating: dataset_nlg_v1/data/223685202390697.csv
#   inflating: dataset_nlg_v1/data/10183635037126615614.csv
#   inflating: dataset_nlg_v1/data/10598378919040887830.csv
#   inflating: dataset_nlg_v1/data/16849832569717941381.csv
#   inflating: dataset_nlg_v1/data/2959284039390075133.csv
#   inflating: dataset_nlg_v1/data/16048477271315512217.csv
#   inflating: dataset_nlg_v1/data/14826965911600865957.csv
#   inflating: dataset_nlg_v1/data/8803314375938631355.csv
#   inflating: dataset_nlg_v1/data/17253781273064184427.csv
#   inflating: dataset_nlg_v1/data/13512420533897444048.csv
#   inflating: dataset_nlg_v1/data/223685202386691.csv
#   inflating: dataset_nlg_v1/data/13904960663763443097.csv
#   inflating: dataset_nlg_v1/data/13595693673753549396.csv
#   inflating: dataset_nlg_v1/data/15877924533351905064.csv
#   inflating: dataset_nlg_v1/data/8976632274792409834.csv
#   inflating: dataset_nlg_v1/data/7393120315073845942.csv
#   inflating: dataset_nlg_v1/data/12490299933049469722.csv
#   inflating: dataset_nlg_v1/data/17507731277474794197.csv
#   inflating: dataset_nlg_v1/data/4963807950742789783.csv
#   inflating: dataset_nlg_v1/data/13008148968035895413.csv
#   inflating: dataset_nlg_v1/data/223685202395750.csv
#   inflating: dataset_nlg_v1/data/1580061990682756874.csv
#   inflating: dataset_nlg_v1/data/2967732914191906485.csv
#   inflating: dataset_nlg_v1/data/13992340589236348606.csv
#   inflating: dataset_nlg_v1/data/8435581057428053922.csv
#   inflating: dataset_nlg_v1/data/17514747610680145999.csv
#   inflating: dataset_nlg_v1/data/10227152776032889417.csv
#   inflating: dataset_nlg_v1/data/223685202386350.csv
#   inflating: dataset_nlg_v1/data/17754326306938359715.csv
#   inflating: dataset_nlg_v1/data/7258887964356629217.csv
#   inflating: dataset_nlg_v1/data/15382951112937455934.csv
#   inflating: dataset_nlg_v1/data/9726888884028176217.csv
#   inflating: dataset_nlg_v1/data/1182294091671622602.csv
#   inflating: dataset_nlg_v1/data/223685202386617.csv
#   inflating: dataset_nlg_v1/data/11681046503354377219.csv
#   inflating: dataset_nlg_v1/data/223685202394715.csv
#   inflating: dataset_nlg_v1/data/223685202396469.csv
#   inflating: dataset_nlg_v1/data/15434369144402989944.csv
#   inflating: dataset_nlg_v1/data/461532293751319920.csv
#   inflating: dataset_nlg_v1/data/9393835377059389689.csv
#   inflating: dataset_nlg_v1/data/3493500911778435415.csv
#   inflating: dataset_nlg_v1/data/223685202395525.csv
#   inflating: dataset_nlg_v1/data/2024284312623226341.csv
#   inflating: dataset_nlg_v1/data/7518231955264543393.csv
#   inflating: dataset_nlg_v1/data/223685202395702.csv
#   inflating: dataset_nlg_v1/data/1134222174109736265.csv
#   inflating: dataset_nlg_v1/data/223685202388894.csv
#   inflating: dataset_nlg_v1/data/223685202392336.csv
#   inflating: dataset_nlg_v1/data/10339115480306364414.csv
#   inflating: dataset_nlg_v1/data/699234696920826058.csv
#   inflating: dataset_nlg_v1/data/223685202394475.csv
#   inflating: dataset_nlg_v1/data/223685202386244.csv
#   inflating: dataset_nlg_v1/data/223685202396488.csv
#   inflating: dataset_nlg_v1/data/8815965871353901813.csv
#   inflating: dataset_nlg_v1/data/4596815410832769444.csv
#   inflating: dataset_nlg_v1/data/223685202391871.csv
#   inflating: dataset_nlg_v1/data/1284311682492624418.csv
#   inflating: dataset_nlg_v1/data/223685202395715.csv
#   inflating: dataset_nlg_v1/data/223685202395190.csv
#   inflating: dataset_nlg_v1/data/223685202392112.csv
#   inflating: dataset_nlg_v1/data/16214527890127601101.csv
#   inflating: dataset_nlg_v1/data/15518419648244344039.csv
#   inflating: dataset_nlg_v1/data/6567503213724060105.csv
#   inflating: dataset_nlg_v1/data/2774479827949778526.csv
#   inflating: dataset_nlg_v1/data/4918628638648546077.csv
#   inflating: dataset_nlg_v1/data/223685202390258.csv
#   inflating: dataset_nlg_v1/data/8896962763384307078.csv
#   inflating: dataset_nlg_v1/data/13144521717157862903.csv
#   inflating: dataset_nlg_v1/data/5850122724052420216.csv
#   inflating: dataset_nlg_v1/data/223685202388889.csv
#   inflating: dataset_nlg_v1/data/819677037091462081.csv
#   inflating: dataset_nlg_v1/data/10315085131815161555.csv
#   inflating: dataset_nlg_v1/data/3312192469852599003.csv
#   inflating: dataset_nlg_v1/data/13101362950919630059.csv
#   inflating: dataset_nlg_v1/data/223685202388344.csv
#   inflating: dataset_nlg_v1/data/18119235837447216822.csv
#   inflating: dataset_nlg_v1/data/223685202385983.csv
#   inflating: dataset_nlg_v1/data/8313982873206389325.csv
#   inflating: dataset_nlg_v1/data/223685202396307.csv
#   inflating: dataset_nlg_v1/data/12502211197590890452.csv
#   inflating: dataset_nlg_v1/data/5023826196564836476.csv
#   inflating: dataset_nlg_v1/data/1334632137180312282.csv
#   inflating: dataset_nlg_v1/data/223685202390265.csv
#   inflating: dataset_nlg_v1/data/223685202395321.csv
#   inflating: dataset_nlg_v1/data/11417479128984010719.csv
#   inflating: dataset_nlg_v1/data/14441878555503198649.csv
#   inflating: dataset_nlg_v1/data/7971255614170028194.csv
#   inflating: dataset_nlg_v1/data/223685202394027.csv
#   inflating: dataset_nlg_v1/data/4875288733018717460.csv
#   inflating: dataset_nlg_v1/data/14019224042963503069.csv
#   inflating: dataset_nlg_v1/data/10069073477329419131.csv
#   inflating: dataset_nlg_v1/data/10161827760277829994.csv
#   inflating: dataset_nlg_v1/data/223685202394713.csv
#   inflating: dataset_nlg_v1/data/17345184725765742125.csv
#   inflating: dataset_nlg_v1/data/223685202388317.csv
#   inflating: dataset_nlg_v1/data/10595852903447425826.csv
#   inflating: dataset_nlg_v1/data/3885234254208881008.csv
#   inflating: dataset_nlg_v1/data/223685202390503.csv
#   inflating: dataset_nlg_v1/data/223685202391474.csv
#   inflating: dataset_nlg_v1/data/5920930556439450200.csv
#   inflating: dataset_nlg_v1/data/12220756424572419733.csv
#   inflating: dataset_nlg_v1/data/6813160409847193491.csv
#   inflating: dataset_nlg_v1/data/15299209362736204602.csv
#   inflating: dataset_nlg_v1/data/8542909972059440949.csv
#   inflating: dataset_nlg_v1/data/6111435913326532248.csv
#   inflating: dataset_nlg_v1/data/2957209669094657101.csv
#   inflating: dataset_nlg_v1/data/303550956956861130.csv
#   inflating: dataset_nlg_v1/data/11678438608037570823.csv
#   inflating: dataset_nlg_v1/data/4004438327869429730.csv
#   inflating: dataset_nlg_v1/data/7440535437339471369.csv
#   inflating: dataset_nlg_v1/data/3036897181270667039.csv
#   inflating: dataset_nlg_v1/data/10518220043046488211.csv
#   inflating: dataset_nlg_v1/data/223685202386578.csv
#   inflating: dataset_nlg_v1/data/223685202395231.csv
#   inflating: dataset_nlg_v1/data/4613634199606847207.csv
#   inflating: dataset_nlg_v1/data/223685202391063.csv
#   inflating: dataset_nlg_v1/data/11377728060364376785.csv
#   inflating: dataset_nlg_v1/data/17364609565181297359.csv
#   inflating: dataset_nlg_v1/data/10713478765274952987.csv
#   inflating: dataset_nlg_v1/data/14095161185670518688.csv
#   inflating: dataset_nlg_v1/data/11008408988858183847.csv
#   inflating: dataset_nlg_v1/data/223685202387228.csv
#   inflating: dataset_nlg_v1/data/10853399916366722657.csv
#   inflating: dataset_nlg_v1/data/16797909030234182059.csv
#   inflating: dataset_nlg_v1/data/11604874088544434958.csv
#   inflating: dataset_nlg_v1/data/13785037495176671434.csv
#   inflating: dataset_nlg_v1/data/2096991922883497375.csv
#   inflating: dataset_nlg_v1/data/5154313182684900188.csv
#   inflating: dataset_nlg_v1/data/223685202388314.csv
#   inflating: dataset_nlg_v1/data/5319387216849494733.csv
#   inflating: dataset_nlg_v1/data/6325247503148801574.csv
#   inflating: dataset_nlg_v1/data/518766016396313894.csv
#   inflating: dataset_nlg_v1/data/1638635537389601624.csv
#   inflating: dataset_nlg_v1/data/9346641436369736318.csv
#   inflating: dataset_nlg_v1/data/1862769365344913898.csv
#   inflating: dataset_nlg_v1/data/10942965091275701198.csv
#   inflating: dataset_nlg_v1/data/17685907330841656898.csv
#   inflating: dataset_nlg_v1/data/4038077247782355109.csv
#   inflating: dataset_nlg_v1/data/3503046488412280477.csv
#   inflating: dataset_nlg_v1/data/1013878421787865588.csv
#   inflating: dataset_nlg_v1/data/15645197728616136575.csv
#   inflating: dataset_nlg_v1/data/2694751921653220179.csv
#   inflating: dataset_nlg_v1/data/4884186364636065934.csv
#   inflating: dataset_nlg_v1/data/584592121486372098.csv
#   inflating: dataset_nlg_v1/data/223685202396139.csv
#   inflating: dataset_nlg_v1/data/14308629323526431848.csv
#   inflating: dataset_nlg_v1/data/7326498787617046732.csv
#   inflating: dataset_nlg_v1/data/223685202393455.csv
#   inflating: dataset_nlg_v1/data/3285776723983728967.csv
#   inflating: dataset_nlg_v1/data/223685202391486.csv
#   inflating: dataset_nlg_v1/data/18160840408573815488.csv
#   inflating: dataset_nlg_v1/data/8479362996130695374.csv
#   inflating: dataset_nlg_v1/data/14873640447795554808.csv

# %%
data = pd.read_csv(f'{dataset_path}/train.csv', index_col=0)
data.head(5)
# Out:
#                                                                    text  \
# 871923758931292416    This statistic presents the global revenue of ...
# 12713542298181105208  This statistic shows the number of hotel and s...
# 5796511258704617257   In 2019 , just 2.5 percent of all private wage...
# 14629703118053421010  This statistic displays the benefits of using ...
# 14801098692472737046  The statistic shows global gross domestic prod...
#
#                                                                   title
# 871923758931292416    Omnicom Group 's revenue from 2006 to 2019 ( i...
# 12713542298181105208  Number of hotel and similar accommodation esta...
# 5796511258704617257   Unemployment rate in the U.S. broadcasting ind...
# 14629703118053421010  If a â€œconnected deviceâ€ ? had the following...
# 14801098692472737046  Global gross domestic product ( GDP ) at curre...

# %%
sample = pd.read_csv(f'{dataset_path}/data/871923758931292416.csv', index_col=0)
sample
# Out:
#     Year  Revenue in billion U.S. dollars
# 0   2019                            14.95
# 1   2018                            15.29
# 2   2017                            15.27
# 3   2016                            15.42
# 4   2015                            15.13
# 5   2014                            15.32
# 6   2013                            14.58
# 7   2012                            14.22
# 8   2011                            13.87
# 9   2010                            12.54
# 10  2009                            11.72
# 11  2008                            13.36
# 12  2007                            12.69
# 13  2006                            11.38

# %%
submission = pd.read_csv(f'{dataset_path}/submission.csv', index_col=0)
submission.head(5)
# Out:
#                  text  title
# 223685202396506   NaN    NaN
# 223685202396505   NaN    NaN
# 223685202396504   NaN    NaN
# 223685202396503   NaN    NaN
# 223685202396502   NaN    NaN

# %% [markdown]
# - (**5 pts**) Propose and implement at least 2 variants of the input data preprocessing from tables to string data.
# - (**5 pts**) Fine-tune [T5](https://huggingface.co/docs/transformers/model_doc/t5) as a baseline using `t5-base` checkpoint ([paper](https://arxiv.org/pdf/1910.10683.pdf)). In order to handle 2 types of output, test usage of prefixes for T5 model.
# - (**5 pts**) Propose and implement at least 2 variants of data augmentation, retune T5 and compare performance.
# - (**5 pts**) Add domain adoptation via additional Masked language modeling loss (MLM, [paper, section 3.1, Task #1](https://arxiv.org/pdf/1810.04805.pdf)) loss term for encoder, provide hyperparameter search for the regularization parameter $\lambda$, use BERTScore as objective, compare performance:
# $$L(x, y) = -LogLikelihood(x, y) + \lambda L_{MLM}(x_{masked}, x)$$
#
#
# The following metrics should be reported:
# - [SacreBLEU](https://github.com/mjpost/sacrebleu)
# - [ROUGEL](https://github.com/google-research/google-research/tree/master/rouge)
# - [METEOR](https://www.nltk.org/_modules/nltk/translate/meteor_score.html)
# - [BERTScore](https://github.com/Tiiiger/bert_score) using `bert-base-uncased` checkpoint and 9th layer output
#
# Using the best checkpoint from above prepare submission file `submission.csv`, where index is a table caption from the `data` folder, and report the link on your finetuned checkpoint.

# %%
#Processing 1 way
def process_data(dataframe):
    series = dataframe.stack().reset_index()
    series.columns = ['index', 'column', 'value']
    series['column'] = series['column'].str.lower()
    series['info'] = series['column'] + ': ' + series['value'].astype(str)
    main_info = series.groupby('index')['info'].apply('; '.join).reset_index(drop=True)
    return '\n '.join(main_info)

df = pd.read_csv(f'{dataset_path}/data/871923758931292416.csv', index_col=0)
main_info = process_data(df)
print(main_info)
# Out:
# year: 2019.0; revenue in billion u.s. dollars: 14.95
#  year: 2018.0; revenue in billion u.s. dollars: 15.29
#  year: 2017.0; revenue in billion u.s. dollars: 15.27
#  year: 2016.0; revenue in billion u.s. dollars: 15.42
#  year: 2015.0; revenue in billion u.s. dollars: 15.13
#  year: 2014.0; revenue in billion u.s. dollars: 15.32
#  year: 2013.0; revenue in billion u.s. dollars: 14.58
#  year: 2012.0; revenue in billion u.s. dollars: 14.22
#  year: 2011.0; revenue in billion u.s. dollars: 13.87
#  year: 2010.0; revenue in billion u.s. dollars: 12.54
#  year: 2009.0; revenue in billion u.s. dollars: 11.72
#  year: 2008.0; revenue in billion u.s. dollars: 13.36
#  year: 2007.0; revenue in billion u.s. dollars: 12.69
#  year: 2006.0; revenue in billion u.s. dollars: 11.38

# %%
#Processing 2 way
def process_data2(dataframe):
    main_info = dataframe.apply(lambda row: '; '.join([f'{col.lower()}: {row[col]}' for col in row.index if col != 'main_info']), axis=1)
    return '\n'.join(main_info)

df = pd.read_csv(f'{dataset_path}/data/871923758931292416.csv', index_col=0)
main_info = process_data2(df)
print(main_info)
# Out:
# year: 2019.0; revenue in billion u.s. dollars: 14.95
# year: 2018.0; revenue in billion u.s. dollars: 15.29
# year: 2017.0; revenue in billion u.s. dollars: 15.27
# year: 2016.0; revenue in billion u.s. dollars: 15.42
# year: 2015.0; revenue in billion u.s. dollars: 15.13
# year: 2014.0; revenue in billion u.s. dollars: 15.32
# year: 2013.0; revenue in billion u.s. dollars: 14.58
# year: 2012.0; revenue in billion u.s. dollars: 14.22
# year: 2011.0; revenue in billion u.s. dollars: 13.87
# year: 2010.0; revenue in billion u.s. dollars: 12.54
# year: 2009.0; revenue in billion u.s. dollars: 11.72
# year: 2008.0; revenue in billion u.s. dollars: 13.36
# year: 2007.0; revenue in billion u.s. dollars: 12.69
# year: 2006.0; revenue in billion u.s. dollars: 11.38

# %%
X_train_ind, X_val_ind, y_train, y_val = train_test_split(data.index.values, data.values, test_size=0.2, random_state=42) #y[text, values]

my_token = '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'
model = T5ForConditionalGeneration.from_pretrained("t5-base", token=my_token).to(device)
tokenizer = T5Tokenizer.from_pretrained("t5-base", token=my_token)


class CSVDataset(torch.utils.data.Dataset):
  def __init__(self, csv_indices, data):
    self.csv_indices = csv_indices
    self.database = pd.DataFrame({'main_info': [self.summarize(fileindex) for fileindex in tqdm(self.csv_indices, unit_divisor=5000)]}, index = self.csv_indices)
    self.database['text'] = data[:, 0]
    self.database['title'] = data[:, 1]

  def summarize(self, index):
    df = pd.read_csv(f'{dataset_path}/data/{index}.csv', index_col=0)
    main_info = df.apply(lambda row: '; '.join([f'{col.lower()}: {row[col]}' for col in row.index if col != 'main_info']), axis=1)
    return '\n'.join(main_info)

  def __getitem__(self, index):

    main_info = self.database.loc[self.csv_indices[index], 'main_info']
    # inputs = tokenizer.encode(main_info, return_tensors="pt", max_length=128, truncation=True, padding='max_length')
    inputs = tokenizer(main_info, return_tensors='pt', max_length=128, truncation=True, padding='max_length', return_token_type_ids=False).to(device)

    reference_text = self.database.loc[self.csv_indices[index], 'text']
    # targets_text = tokenizer.encode(reference_text, return_tensors="pt", max_length=128, truncation=True, padding='max_length')
    targets_text = tokenizer.encode_plus(reference_text, return_tensors='pt', max_length=128, truncation=True, padding='max_length', return_token_type_ids=False).to(device)

    reference_title = self.database.loc[self.csv_indices[index], 'title']
    # targets_title = tokenizer.encode(reference_title, return_tensors="pt", max_length=128, truncation=True, padding='max_length')
    targets_title = tokenizer(reference_title, return_tensors='pt', max_length=128, truncation=True, padding='max_length', return_token_type_ids=False).to(device)

    # results = [tensor[0, :] for tensor in [inputs, targets_text, targets_title]]
    return inputs, targets_text, targets_title

  def __len__(self):
    return len(self.database)

train_dataset = CSVDataset(X_train_ind, y_train)
val_dataset = CSVDataset(X_val_ind, y_val)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=8, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=8, shuffle=False)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 100%|██████████| 20256/20256 [00:48<00:00, 414.69it/s]
# 100%|██████████| 5065/5065 [00:20<00:00, 243.57it/s]

# %%
def get_metrics_sample(reference, hypothesis):
    # BLEU score
    cheng_lapata = SmoothingFunction()
    BLEU_score = sentence_bleu(reference, hypothesis, smoothing_function=cheng_lapata.method4)

    # ROUGE score
    rouge_scorer_obj = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)
    rg_score = rouge_scorer_obj.score(' '.join(hypothesis), ' '.join(reference))['rougeL'].precision

    reference_tokens = nltk.word_tokenize(reference.lower())
    hypothesis_tokens = nltk.word_tokenize(hypothesis.lower())

    reference_tokens = [token for token in reference_tokens if token.isalnum()]
    hypothesis_tokens = [token for token in hypothesis_tokens if token.isalnum()]

    meteor = single_meteor_score(reference_tokens, hypothesis_tokens)

    # BERT score
    bert_score_obj = score([hypothesis], [reference], model_type='bert-base-uncased', num_layers=9)
    bert_score = float(score([hypothesis], [reference], model_type='bert-base-uncased', num_layers=9)[0])

    return {
        'BLEU': BLEU_score,
        'ROUGE': rg_score,
        'METEOR': meteor,
        'BERT': bert_score
    }


def train_epoch(model, train_loader, optimizer, loss_fn, device, scheduler):
    model.train()
    avg_loss = 0.0

    for inputs_data in train_loader:
        optimizer.zero_grad()
        inputs, targets_text, targets_title = inputs_data
        inputs, targets_text, targets_title = inputs.to(device), targets_text.to(device), targets_title.to(device)
        outputs_text = model(inputs['input_ids'][:, 0, :], inputs['attention_mask'][:, 0, :], labels = inputs['input_ids'][:, 0, :])
        outputs_title = model(inputs['input_ids'][:, 0, :], inputs['attention_mask'][:, 0, :], labels = inputs['input_ids'][:, 0, :])
        print(outputs_text)
        print(outputs_title)
        loss = loss_fn(outputs_text, targets_text) + loss_fn(outputs_title, targets_title)
        loss.backward()
        optimizer.step()
        avg_loss += loss.item()
    avg_loss /= len(train_loader)

    if scheduler is not None:
        scheduler.step(avg_loss)

    return avg_loss

def eval_epoch(model, val_loader, loss_fn, device, get_metrics=False):
    avg_loss = 0.0
    metrics = {'texts': {'BLEU': [], 'ROUGE': [], 'METEOR': [], 'BERT': []},
               'titles': {'BLEU': [], 'ROUGE': [], 'METEOR': [], 'BERT': []}}
    with torch.no_grad():
      for inputs_data in val_loader:
          inputs, targets_text, targets_title = inputs_data
          inputs, targets_text, targets_title = inputs.to(device), targets_text.to(device), targets_title.to(device)
          outputs_text = model(inputs['input_ids'][:, 0, :], inputs['attention_mask'][:, 0, :], labels = inputs['input_ids'][:, 0, :])
          outputs_title = model(inputs['input_ids'][:, 0, :], inputs['attention_mask'][:, 0, :], labels = inputs['input_ids'][:, 0, :])
          if get_metrics:
            for reference, hypothesis in zip(targets_text, outputs_text):
                metric = get_metrics_sample(reference, hypothesis)
                for key in metric:
                    metrics['texts'][key].append(metric[key])
            for reference, hypothesis in zip(targets_title, outputs_title):
                metric = get_metrics_sample(reference, hypothesis)
                for key in metric:
                    metrics['titles'][key].append(metric[key])
          loss = loss_fn(outputs_text, targets_text).item() + loss_fn(outputs_title, targets_title).item()
          avg_loss += loss
      avg_loss /= len(train_loader)

    if get_metrics:
      for key in metrics['texts']:
          metrics['texts'][key] = sum(metrics['texts'][key]) / len(val_loader)
      for key in metrics['titles']:
          metrics['titles'][key] = sum(metrics['titles'][key]) / len(val_loader)
      return metrics, avg_loss
    else:
      return avg_loss

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode = 'min')
num_epochs = 10
early_stopping = 3
best_loss = 999.999

for epoch in range(num_epochs):
  print(f"Epoch {epoch}")
  train_loss = train_epoch(model, train_loader, optimizer, loss_fn, device=device, scheduler=scheduler)
  print(f"Train loss {train_loss:.3f}")
  val_loss = val_epoch(model, val_loader, loss_fn, device=device)
  if val_loss < best_loss:
    best_loss = val_loss
    stop_iter = 0
    torch.save(model.state_dict(), 'best_model.pt')
  else:
    stop_iter += 1
  print(f"Val loss {val_loss:.3f}. Best val loss = {best_loss:.3f}")

metrics = val_epoch(model, val_loader, loss_fn, device=device, get_metrics = True)
texts_result_base = pd.DataFrame(metrics['texts'])
titles_result_base = pd.DataFrame(metrics['titles'])
# Out:
# Epoch 0
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# <ipython-input-42-1e3b8deb254a> in <cell line: 8>()
#       8 for epoch in range(num_epochs):
#       9   print(f"Epoch {epoch}")
# ---> 10   train_loss = train_epoch(model, train_loader, optimizer, loss_fn, device=device, scheduler=scheduler)
#      11   print(f"Train loss {train_loss:.3f}")
#      12   val_loss = val_epoch(model, val_loader, loss_fn, device=device)
#
# <ipython-input-41-c514da30b6e4> in train_epoch(model, train_loader, optimizer, loss_fn, device, scheduler)
#      36         inputs, targets_text, targets_title = inputs_data
#      37         inputs, targets_text, targets_title = inputs.to(device), targets_text.to(device), targets_title.to(device)
# ---> 38         outputs_text = model(inputs['input_ids'][:, 0, :], inputs['attention_mask'][:, 0, :], labels = inputs['input_ids'][:, 0, :])
#      39         outputs_title = model(inputs['input_ids'][:, 0, :], inputs['attention_mask'][:, 0, :], labels = inputs['input_ids'][:, 0, :])
#      40         print(outputs_text)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1740
#    1741         # Decode
# -> 1742         decoder_outputs = self.decoder(
#    1743             input_ids=decoder_input_ids,
#    1744             attention_mask=decoder_attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1107                 )
#    1108             else:
# -> 1109                 layer_outputs = layer_module(
#    1110                     hidden_states,
#    1111                     attention_mask=extended_attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict)
#     717                 query_length = None
#     718
# --> 719             cross_attention_outputs = self.layer[1](
#     720                 hidden_states,
#     721                 key_value_states=encoder_hidden_states,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, hidden_states, key_value_states, attention_mask, position_bias, layer_head_mask, past_key_value, use_cache, query_length, output_attentions)
#     628     ):
#     629         normed_hidden_states = self.layer_norm(hidden_states)
# --> 630         attention_output = self.EncDecAttention(
#     631             normed_hidden_states,
#     632             mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, hidden_states, mask, key_value_states, position_bias, past_key_value, layer_head_mask, query_length, use_cache, output_attentions)
#     519             hidden_states, self.k, key_value_states, past_key_value[0] if past_key_value is not None else None
#     520         )
# --> 521         value_states = project(
#     522             hidden_states, self.v, key_value_states, past_key_value[1] if past_key_value is not None else None
#     523         )
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/modeling_t5.py in project(hidden_states, proj_layer, key_value_states, past_key_value)
#     494                 # cross-attn
#     495                 # (batch_size, n_heads, seq_length, dim_per_head)
# --> 496                 hidden_states = shape(proj_layer(key_value_states))
#     497
#     498             if past_key_value is not None:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     114
#     115     def forward(self, input: Tensor) -> Tensor:
# --> 116         return F.linear(input, self.weight, self.bias)
#     117
#     118     def extra_repr(self) -> str:
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 20.00 MiB. GPU 0 has a total capacity of 14.75 GiB of which 9.06 MiB is free. Process 5690 has 14.74 GiB memory in use. Of the allocated memory 13.83 GiB is allocated by PyTorch, and 802.51 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
# Your code is here

# %% [markdown]
# ## Reranking approach (15 pts)
#
# Using maximum likelihood, an ideal model will assign all probability mass to the reference summary. During inference, the model must also generate the output based on possibly erroneous previous steps. This can affect the performance of the model, a phenomenon often called exposure bias. One way to solve this problem is to require our model to be able to accurately predict the ranking order of a set of most likely candidates via an additional contrastive loss term
#
# $$L(x, y) = -LogLikelihood(x, y) + L_{contrastive}(x, y)$$
#
# where
#
# $$
# L_{contrastive}(x, y) = \sum_i\sum_{j < i}\max(0, f(s_i(x)) - f(s_j(x)) + \alpha_{ij})
# $$
#
# where $\alpha_{ij} = \alpha \cdot (i - j)$ is a margin, $s_i$ and $s_j$ are different candidates (generated by [beam search](https://huggingface.co/blog/how-to-generate)) such that for selected ranking function $r$ $r(s_j, y) > r(s_i, y)$, and
# $f(s)$ is a length-normalised estimated log-probability:
#
# $$
# f(s) = \frac{\sum_{t} LogProb(s_t| s_{<t}, x)}{|x|},
# $$
#
# where $|x|$ is a lenght of $x$.
#
# Your task is to fine-tune the model with reranking-aware loss using BERTScore as the ranking function $r$, provide hyperparameter search for the margin scaling factor $\alpha$ using BERTScore as objective, report metrics for the best case (SacreBLEU, ROUGEL, METEOR, BERTScore), and prepare the submission file `submission_reranking.csv` and report the link on your finetuned checkpoint.

# %%
# Your code is here

# %%
import gc
gc.collect()
torch.cuda.empty_cache()
del model
